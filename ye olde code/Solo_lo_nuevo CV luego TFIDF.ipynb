# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/politext/blob/main/Solo_lo_nuevo%20CV%20luego%20TFIDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cargar la base

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
base=pd.read_csv('/content/drive/MyDrive/base_formateada.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords=stopwords.words('spanish')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Se incorporan las stopwords sugeridas por Federico
stopwords.extend(['señor', 'señora', 'mucha', 'gracia', 'año', 'pasado', 'cada', 'vez', 'uno', 'dos', 'tres', 'cuatro', 'cinco', 'seis' ,'siete', 'ocho', 'nueve', 'diez'])
stopwords.extend(['hoy', 'aquí', 'primer', 'lugar', 'primera', 'segunda', 'primero', 'segundo', 'siguiente', 'tercer'])
stopwords.extend(['convergencia', 'esquerra', 'republicana', 'grupo', 'parlamentaria', 'parlamentario', 'partido'])
stopwords.extend(['enmienda', 'votación', 'favor', 'abstención', 'ley', 'real', 'decreto', 'decretoley', 'resultado', 'voto', 'sé' ,'sí', 'silencio' ,'favor'])
stopwords.extend(['usted', 'señoría', 'presidente', 'presidenta', 'ministro', 'orden' , 'día', 'palabra', 'petición', 'posición', 'punto', 'vista', 'sesión', 'baldoví', 'duran', 'turno'])
stopwords.extend(['hacer', 'frente', 'puede' ,'ser', 'va', 'voy', 'decir'])
stopwords.extend(['millón', 'euro', 'emitido', 'efectuada', 'dio', 'comienzo', 'partido', 'queda', 'quedan', 'rechazada', 'aceptada', 'comienza', 'usted', 'sabe', 'abstención', 'diputado', 'gobierno'])
stopwords.extend(['continuación', 'votamos', 'telemático', 'republicanaizquierda', 'unidainiciativa', 'puede', 'bien', 'propuesta' ,'abstencion', 'mayoría', 'absoluta', 'pregunta', 'don', 'vamos', 'votar', 'llevar', 'cabo', 'millón', 'muchas', 'gracias'])

# %%
# Se incorporan los nombres de los oradores como stopwords
nombres=[]
for i in base.namey.unique().tolist(): nombres.extend(str(i).split(','))
nombres = [x.strip(' ') for x in nombres]
nombres = [x.strip(' †') for x in nombres]
stopwords.extend(nombres)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# CV que conserva solo los términos que no están en el 5% más frecuente ni en el 75% menos frecuente

# Primero selecciono los bigramas de mayor frecuencia (el hiperparámetro max_features selecciona siempre los n-gramas indicados de mayor frecuencia)
vect = CountVectorizer(ngram_range=[2,2], stop_words=stopwords)
bow = vect.fit_transform(base['tokens'])
total_features = len(vect.vocabulary_)
top_vect =  CountVectorizer(ngram_range=[2,2], stop_words=stopwords, max_features=int(total_features * 0.05))
top_bow = top_vect.fit_transform(base['tokens'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abad', 'abascal', 'abeilhe', 'abejón', 'abel', 'aburto', 'acebes', 'acedo', 'acevedo', 'achutegui', 'acosta', 'acín', 'acítores', 'adela', 'adelaida', 'adolfo', 'adriana', 'adriano', 'adrover', 'adsuar', 'adámez', 'adán', 'agius', 'agramunt', 'aguado', 'aguerri', 'aguilar', 'aguilera', 'aguiriano', 'aguirre', 'agustín', 'ahuja', 'aizpún', 'aja', 'alarcón', 'alba', 'albaladejo', 'albendea', 'alberdi', 'albero', 'alberto', 'albiach', 'albiñana', 'alborch', 'albéniz', 'alcalde', 'alcaraz', 'alcañiz', 'alconchel', 'alcover', 'alcázar', 'aldea', 'aledo', 'alegre', 'alegría', 'alejandro', 'alfonso', 'alfred', 'alfredo', 'alférez', 'alicia', 'alierta', 'alique', 'allende', 'almagro', 'almaraz', 'almunia', 'alonso', 'alvear', 'alzaga', 'alén', 'alós', 'amador', 'amann', 'amarillo', 'amate', 'amelia', 'amigo', 'amilivia', 'amor', 'amparo', 'amuedo', 'ana', 'anastasio', 'anaya', 'andrea', 'andré', 'andrés', 'andréu', 'angelina', 'anguita', 'angulo', 'angustias', 'aniceto', 'anna', 'antich', 'antoliano', 'anton', 'antonaya', 'antoni', 'antonia', 'antonio', 'antón', 'aparicio', 'ara', 'aragonés', 'aranda', 'aranegui', 'arantza', 'aranzábal', 'araya', 'araújo', 'arbat', 'arboledas', 'arca', 'arce', 'arenales', 'arenas', 'ares', 'argany', 'argüello', 'arias', 'arija', 'ariño', 'armando', 'armas', 'armengol', 'arnaez', 'arnau', 'arnáiz', 'arola', 'aroz', 'arqueros', 'arreciado', 'arriola', 'arritokieta', 'arrúe', 'arsenio', 'artemi', 'arteseros', 'arturo', 'arza', 'aránzazu', 'arévalo', 'arístegui', 'ascensión', 'asenjo', 'asensio', 'asian', 'asperilla', 'astarloa', 'asunción', 'asís', 'atanasio', 'atencia', 'atienza', 'atondo', 'augusto', 'aurelio', 'avelino', 'ayala', 'ayllón', 'aymerich', 'ayuso', 'aznar', 'azorín', 'azpiroz', 'azuaga', 'azuara', 'babiano', 'baena', 'baeza', 'bajo', 'bajén', 'balada', 'balaguer', 'balbás', 'baldeón', 'baldomero', 'ballestero', 'ballesteros', 'ballesté', 'balletbò', 'balmaseda', 'bar', 'barahona', 'barba', 'barbadillo', 'barbanoj', 'barber', 'barberán', 'barceló', 'barciela', 'bardisa', 'barnuevo', 'barquero', 'barrachina', 'barragán', 'barranco', 'barreda', 'barreiro', 'barrera', 'barrero', 'barrio', 'barrionuevo', 'barrios', 'barros', 'barrueco', 'barrufet', 'bartolomé', 'bartret', 'barón', 'basagoiti', 'basarte', 'baselga', 'bassets', 'bastarreche', 'bastidas', 'bataller', 'batanero', 'batet', 'batista', 'batlles', 'bausela', 'bautista', 'bayona', 'baños', 'bañuls', 'baón', 'beatriz', 'becana', 'beccaría', 'becerril', 'bedera', 'begoña', 'bel', 'belarmina', 'belda', 'belinchón', 'bella', 'bellido', 'belloch', 'beltrán', 'belén', 'benegas', 'beneyto', 'benito', 'bento', 'benzal', 'benítez', 'berbel', 'berenguer', 'bergareche', 'bergasa', 'berlanga', 'bermejo', 'bermúdez', 'bernabeu', 'bernabé', 'bernal', 'bernarda', 'bernardo', 'bernat', 'berruezo', 'berta', 'bertomeu', 'bertrand', 'berzal', 'bes', 'betancort', 'beviá', 'bibiano', 'biscarolasaga', 'blanc', 'blanca', 'blancas', 'blanch', 'blanco', 'blanquer', 'blanquet', 'blas', 'blasco', 'blázquez', 'boada', 'bocanegra', 'bofill', 'boix', 'bolarín', 'bolaños', 'bolea', 'bombín', 'boned', 'bonilla', 'bonmatí', 'bono', 'boronat', 'borrego', 'borrell', 'bosch', 'bosó', 'botana', 'botella', 'boursault', 'boyer', 'bragulat', 'bravo', 'breva', 'brey', 'brito', 'bru', 'buen', 'bueno', 'bueso', 'buitrón', 'bureta', 'burgo', 'burgos', 'burillo', 'busqueta', 'busquets', 'bustamante', 'bustillo', 'busto', 'bustos', 'buyolo', 'bárcena', 'báscones', 'báñez', 'caamaño', 'caballero', 'cabaña', 'cabañes', 'cabello', 'cabeza', 'cabezas', 'cabezón', 'cabrer', 'cabrera', 'cacho', 'cadenas', 'calabuig', 'calahorro', 'calatayud', 'caldera', 'calderón', 'calero', 'callao', 'calleja', 'callejón', 'calomarde', 'calpe', 'calurano', 'calvache', 'calvo', 'calvín', 'cama', 'camacho', 'ca ...
#   % sorted(inconsistent)

# %%
print(f"De los {total_features} de bigramas totales se identifican los {len(top_vect.vocabulary_)} con más frecuencia.")
# Out:
# De los 8228192 de bigramas totales se identifican los 411409 con más frecuencia.

# %%
# Este es el listado de los bigramas del 5% mayor frecuencia
top_vect.vocabulary_
# Out:
# {'procederá dar': 302484,
#  'artículo reglamento': 26222,
#  'frail poujad': 167606,
#  'cámara correspond': 90966,
#  'presidencia mesa': 294299,
#  'mesa edad': 232576,
#  'si encuentra': 353656,
#  'encuentra sala': 135184,
#  'presidencia pausa': 294326,
#  'tampoco present': 376502,
#  'león máximo': 213842,
#  'máximo rodríguez': 244492,
#  'rodríguez valverd': 342835,
#  'presidencia rodríguez': 294376,
#  'ocupa presidencia': 257244,
#  'tome posesión': 385878,
#  'mismo ruego': 238068,
#  'pérez lópez': 316312,
#  'miranda garcía': 236381,
#  'ocupen puesto': 257353,
#  'gonzález pérez': 176354,
#  'lópez alvarez': 218822,
#  'alvarez miranda': 17446,
#  'nombr mesa': 250594,
#  'ss ss': 370606,
#  'mejor ánimo': 229427,
#  'alta misión': 16870,
#  'perdonen ss': 272249,
#  'fi gura': 161008,
#  'socialista obrero': 366088,
#  'obrero español': 256156,
#  'clase servicio': 55758,
#  'servicio nación': 351885,
#  'tribuna pública': 393078,
#  'pública siendo': 317389,
#  'siendo joven': 357426,
#  'intervencion cámara': 203218,
#  'socialista aunqu': 365081,
#  'aunqu forma': 31338,
#  'mismo espíritu': 237538,
#  'espíritu mismo': 147756,
#  'mismo deseo': 237447,
#  'legislatura próxima': 213244,
#  'espero socialista': 147648,
#  'socialista españa': 365562,
#  'justicia libertad': 209733,
#  'libertad aplauso': 213945,
#  'presidencia cámara': 294189,
#  'media hora': 226331,
#  'fin puedan': 161817,
#  'puedan poner': 314411,
#  'poner acuerdo': 285732,
#  'mesa acuerdo': 232538,
#  'acuerdo asentimiento': 5668,
#  'asentimiento levanta': 26744,
#  'levanta doce': 213706,
#  'doce meno': 121818,
#  'meno cuarto': 230602,
#  'dar lectura': 94104,
#  'leído acuerdo': 213750,
#  'secretario dar': 346924,
#  'lectura inform': 212005,
#  'inform junta': 196223,
#  'junta elector': 208582,
#  'leído inform': 213780,
#  'elector central': 129880,
#  'lectura lista': 212009,
#  'pue correspond': 313103,
#  'lista van': 214833,
#  'van depositando': 399073,
#  'depositando urna': 105897,
#  'urna papeleta': 397228,
#  'escrutinio terminado': 140077,
#  'terminado escrutinio': 380792,
#  'escrutinio dijo': 140070,
#  'landelino lavilla': 211488,
#  'lavilla alsina': 211873,
#  'lui gómez': 217894,
#  'gómez llorent': 178346,
#  'gallego bezar': 171849,
#  'adolfo suárez': 10076,
#  'suárez gonzález': 374562,
#  'gonzález fernando': 176317,
#  'fernando abril': 160795,
#  'abril martorel': 650,
#  'castel ferrer': 46913,
#  'dado avanzado': 93280,
#  'avanzado hora': 34152,
#  'mesa propon': 232633,
#  'media tard': 226427,
#  'tard rumor': 377441,
#  'rumor acuerdo': 343303,
#  'acuerdo mesa': 6373,
#  'suspend tard': 374303,
#  'tard minuto': 377368,
#  'minuto tard': 236338,
#  'tard reanuda': 377430,
#  'reanuda quinc': 325359,
#  'quinc minuto': 321246,
#  'proced elección': 302258,
#  'elección vicepresident': 129852,
#  'solament debe': 367855,
#  'nombr papeleta': 250613,
#  'depositando papeleta': 105896,
#  'papeleta urna': 262233,
#  'modesto frail': 239603,
#  'doña maría': 122557,
#  'maría victoria': 223585,
#  'fernándezespaña fernándezlatorr': 160898,
#  'proclamado vicepresident': 303477,
#  'pausa secretario': 267910,
#  'terminada dijo': 380780,
#  'comenzar escrutinio': 57654,
#  'efectuado escrutinio': 127694,
#  'maría izquierdo': 223533,
#  'izquierdo rojo': 206767,
#  'becerril bustamant': 37693,
#  'leopoldo torr': 213597,
#  'torr boursault': 386177,
#  'alfonso guerra': 15485,
#  'guerra gonzález': 177859,
#  'felip gonzález': 160712,
#  'gonzález márquez': 176341,
#  'nombrado secretario': 250727,
#  'secretario tercero': 346985,
#  'secretario cuarto': 346921,
#  'presidencia ruega': 294378,
#  'mesa sido': 232652,
#  'sido elegida': 355707,
#  'misma composición': 236607,
#  'composición mesa': 61161,
#  'vicepresident tercero': 403584,
#  'vicepresident cuarto': 403478,
#  'doña soledad': 122583,
#  'soledad becerril': 368161,
#  'tomar posesión': 385800,
#  'ocupan puesto': 257327,
#  'clase alguna': 55720,
#  'alguna quiero': 15921,
#  'quiero expresar': 320909,
#  'expresar brevement': 157514,
#  'propio nombr': 307874,
#  'nombr demá': 250535,
#  'creo debo': 82427,
#  'debo expresar': 98472,
#  'hacerm eco': 182379,
#  'totalidad cámara': 386561,
#  'cámara agradecimiento': 90697,
#  'gran rigor': 176917,
#  'identidad política': 188404,
#  'cualquiera sido': 85367,
#  'significación política': 357989,
#  'cámara dado': 91011,
#  'dado misma': 93465,
#  'misma órgano': 237170,
#  'órgano necesario': 409705,
#  'necesario funcionamiento': 247372,
#  'funcionamiento cuanto': 169001,
#  'cuanto titular': 86105,
#  'cámara conjunto': 90903,
#  'conjunto pueden': 66869,
#  'pueden ss': 315007,
#  'ss tener': 370620,
#  'tener plena': 380188,
#  'plena seguridad': 280010,
#  'seguridad nunca': 348879,
#  'cámara respeto': 91963,
#  'respeto merecen': 338850,
#  'ss mismo': 370402,
#  'mismo cuanto': 237382,
#  'cuanto representación': 86026,
#  'representación pueblo': 336309,
#  'pueblo español': 313607,
#  'español preocupación': 144404,
#  'falta luego': 159356,
#  'pue blo': 313059,
#  'español espera': 143886,
#  'mo mento': 238612,
#  'firm decisión': 163887,
#  'ejerc funcion': 129060,
#  'término estricto': 394695,
#  'estricto reglamento': 150055,
#  'objetividad imparcialidad': 254376,
#  'aspiración legítima': 27845,
#  'legítima aspiración': 213375,
#  'entiendo buen': 137561,
#  'buen funcionamiento': 39176,
#  'funcionamiento congreso': 168983,
#  'fernando alvarez': 160796,
#  'congreso anterior': 66106,
#  'anterior legislatura': 19280,
#  'legislatura quiero': 213255,
#  'quiero rendir': 321118,
#  'rendir homenaj': 335231,
#  'duda ss': 123199,
#  'ss comparten': 370155,
#  'quiero destacar': 320859,
#  'recordado alguna': 327157,
#  'alguna ocasión': 15864,
#  'ocasión anterior': 256749,
#  'anterior misma': 19315,
#  'misma cámara': 236661,
#  'concepción sistema': 63320,
#  'sistema democrático': 361163,
#  'diálogo diálogo': 121532,
#  'gobernant gobernado': 176169,
#  'hace posibl': 181345,
#  'posibl exist': 289088,
#  'lenguaj común': 213560,
#  'fundamento convivencia': 170687,
#  'convivencia sino': 76957,
#  'sino dan': 359699,
#  'dan supuesto': 93769,
#  'supuesto diálogo': 373721,
#  'diálogo oposición': 121597,
#  'implica reconoc': 189741,
#  'pieza esencial': 277611,
#  'estructura constitucion': 150103,
#  'manera compartir': 219957,
#  'ejercicio poder': 129296,
#  'diálogo poder': 121607,
#  'poder ejecutivo': 281553,
#  'poner peligro': 285853,
#  'peligro estabilidad': 270256,
#  'estabilidad sistema': 147984,
#  'sistema último': 361757,
#  'poder central': 281438,
#  'diversa comunidad': 121227,
#  'comunidad especialment': 62422,
#  'convivencia pueblo': 76953,
#  'pue constitución': 313096,
#  'constitución constitución': 71708,
#  'bajo forma': 36064,
#  'hace parlamento': 181292,
#  'especialment cámara': 146581,
#  'cámara congreso': 90901,
#  'diálogo democracia': 121518,
#  'conocimiento debat': 67562,
#  'debat solución': 96170,
#  'solución problema': 369474,
#  'problema españa': 301231,
#  'españa contamo': 141679,
#  'antecedent próximo': 18937,
#  'nueva democracia': 252103,
#  'cuyo trabajo': 90128,
#  'trabajo eficacia': 388321,
#  'eficacia esfuerzo': 127794,
#  'esfuerzo hacia': 140781,
#  'hacia libertad': 182587,
#  'libertad convivencia': 213988,
#  'tarea legislativa': 377635,
#  'desarrollar futuro': 107530,
#  'diálogo cumplimiento': 121513,
#  'cumplimiento tarea': 89283,
#  'colaboración conseguir': 56861,
#  'conseguir trabajo': 68906,
#  'trabajo cámara': 388215,
#  'cámara serio': 92025,
#  'español parlamento': 144293,
#  'necesario respeto': 247580,
#  'respeto norma': 338868,
#  'norma cámara': 250892,
#  'cámara perjuicio': 91675,
#  'ello depend': 130987,
#  'respeto pueblo': 338912,
#  'pueblo sólo': 313703,
#  'sólo así': 374787,
#  'así pueblo': 29509,
#  'pueblo pueblo': 313676,
#  'expresión mismo': 157642,
#  'mismo fin': 237580,
#  'ejemplo vivo': 129029,
#  'constituy única': 72366,
#  'única vía': 410948,
#  'discrepancia si': 118999,
#  'si hacemo': 353919,
#  'contribuido decisivament': 75347,
#  'crear futuro': 80728,
#  'futuro convivencia': 170885,
#  'establ español': 148040,
#  'español derecho': 143761,
#  'sino reiterar': 360448,
#  'reiterar agradecimiento': 333365,
#  'expresar deseo': 157525,
#  'esperanza creo': 147294,
#  'creo trabajo': 83182,
#  'trabajo congreso': 388140,
#  'asegurar mejor': 26626,
#  'mejor españa': 228983,
#  'españa aplauso': 141385,
#  'conformidad artículo': 65949,
#  'reglamento efecto': 332428,
#  'efecto estrictament': 127399,
#  'próxima reunión': 312397,
#  'reunión pleno': 341741,
#  'pleno miércol': 280256,
#  'miércol tard': 238604,
#  'tard levanta': 377351,
#  'saben ss': 344417,
#  'ss present': 370488,
#  'present sido': 292796,
#  'sido convocada': 355522,
#  'efecto dar': 127327,
#  'dar cumplimiento': 94010,
#  'cumplimiento estricto': 89193,
#  'prevision reglamentaria': 298037,
#  'dación cuenta': 93186,
#  'cuenta diputación': 86780,
#  'diputación permanent': 117743,
#  'funcion congreso': 168649,
#  'congreso período': 66318,
#  'período transcurrido': 275792,
#  'anterior cámara': 19114,
#  'cámara constitución': 90932,
#  'constitución nueva': 71973,
#  'nueva part': 252303,
#  'comisión incompatibilidad': 58413,
#  'elaborar dictamen': 129612,
#  'pertinent relación': 275616,
#  'situación incompatibilidad': 362461,
#  'incompatibilidad miembro': 193803,
#  'relativo comunicacion': 334710,
#  'presi dencia': 294106,
#  'ss desarrollo': 370236,
#  'desarrollo trabajo': 108073,
#  'cámara requier': 91949,
#  'saben perfectament': 344363,
#  'seri tema': 351238,
#  'tema urgent': 379394,
#  'ejemplo tema': 128983,
#  'tema constitución': 378562,
#  'constitución comisión': 71682,
#  'constitución mayor': 71943,
#  'mayor brevedad': 224909,
#  'brevedad posibl': 38829,
#  'posibl perjuicio': 289316,
#  'puedan proced': 314418,
#  'función posibl': 169783,
#  'posibl revisión': 289442,
#  'revisión norma': 341866,
#  'norma reglamentaria': 251124,
#  'quería recordar': 319718,
#  'recordar ss': 327392,
#  'apartado artículo': 20473,
#  'obligado efectuar': 255810,
#  'efectuar declaración': 127701,
#  'aquella actividad': 23640,
#  'ingreso económico': 197451,
#  'reglamento señala': 332532,
#  'declaración si': 99890,
#  'si disposición': 353592,
#  'disposición transitoria': 120247,
#  'transitoria tercera': 390295,
#  'estableció plazo': 149086,
#  'plazo mese': 279757,
#  'mese partir': 232946,
#  'partir aprobación': 266487,
#  'aprobación reglamento': 22451,
#  'acordó reunión': 3227,
#  'reunión ayer': 341675,
#  'mese debe': 232763,
#  'debe regir': 97221,
#  'digo artículo': 116401,
#  'reglamento plazo': 332487,
#  'partir fecha': 266548,
#  'fecha constitución': 160486,
#  'cámara marzo': 91510,
#  'permito recordar': 273808,
#  'ss objeto': 370422,
#  'objeto puedan': 255368,
#  'puedan dar': 314266,
#  'cumplimiento norma': 89226,
#  'permanent congreso': 272940,
#  'congreso pasada': 66316,
#  'pasada legislatura': 266875,
#  'legislatura saben': 213271,
#  'respecto forma': 338061,
#  'forma proced': 166531,
#  'proced cuanto': 302235,
#  'cuenta aunqu': 86613,
#  'precedent inmediato': 290551,
#  'inmediato relación': 198633,
#  'período intersesion': 275722,
#  'ningún tipo': 249953,
#  'tipo control': 383657,
#  'control meno': 75814,
#  'relación actuación': 333710,
#  'permanent anterior': 272921,
#  'anterior congreso': 19076,
#  'cuenta debe': 86735,
#  'debe realizar': 97191,
#  'realizar part': 324951,
#  'permanent carácter': 272929,
#  'carácter formal': 44793,
#  'respecto acto': 337734,
#  'acto decision': 4078,
#  'decision misma': 99266,
#  'aquel momento': 23590,
#  'momento perjuicio': 241531,
#  'perjuicio ello': 272816,
#  'aquello político': 24172,
#  'político representación': 285363,
#  'representación diputación': 336247,
#  'cámara puedan': 91847,
#  'posicion sido': 289746,
#  'sido actuación': 355251,
#  'permanent ello': 272968,
#  'máximo minuto': 244444,
#  'formaron part': 167044,
#  'part diputación': 264676,
#  'formando part': 167026,
#  'part congreso': 264486,
#  'pido cuestión': 277288,
#  'quisiera nombr': 321464,
#  'nombr socialista': 250671,
#  'socialista sientan': 366595,
#  'sientan cámara': 357583,
#  'cámara agradec': 90695,
#  'hecho mismo': 184960,
#  'mismo tiempo': 238153,
#  'manifestar extrañeza': 220859,
#  'cuenta referido': 87181,
#  'relación constitución': 333852,
#  'tratado tema': 391628,
#  'tema cuenta': 378601,
#  'publicación norma': 312691,
#  'establec artículo': 148121,
#  'reglamento ademá': 332352,
#  'reglamento ss': 332540,
#  'toda norma': 384863,
#  'interpretación reglamento': 203116,
#  'ejemplo materia': 128734,
#  'cómputo plazo': 92829,
#  'plazo desarrollo': 279642,
#  'desarrollo artículo': 107643,
#  'artículo así': 25468,
#  'así desarrollo': 28841,
#  'producido sido': 304292,
#  'sido publicada': 356265,
#  'boletín ofici': 38504,
#  'ofici cort': 257790,
#  'final hace': 162076,
#  'dicen toda': 112573,
#  'toda publicacion': 384988,
#  'importancia supon': 190244,
#  'important reglamento': 191302,
#  'seguridad jurídica': 348815,
#  'jurídica saber': 209059,
#  'saber atenerno': 344458,
#  'mayor gravedad': 225199,
#  'gravedad caso': 177621,
#  'caso pediría': 46375,
#  'aspecto reglamentario': 27742,
#  'van afectar': 398920,
#  'presidencia materia': 294294,
#  'situa ción': 361819,
#  'inseguridad jurídica': 199025,
#  'reglamento prevé': 332496,
#  'actuación cámara': 4552,
#  'cámara resolucion': 91951,
#  'pleno despué': 280195,
#  'despué objeto': 109561,
#  'norma ejemplo': 250934,
#  'ejemplo artículo': 128406,
#  'artículo refier': 26214,
#  'refier sólo': 330645,
#  'sólo documento': 375004,
#  'servir base': 352166,
#  'base debat': 37003,
#  'debat caso': 95382,
#  'caso norma': 46306,
#  'norma citado': 250851,
#  'refier intervencion': 330485,
#  'intervencion acuerdo': 203200,
#  'acuerdo producido': 6611,
#  'pública pública': 317266,
#  'pública carácter': 316506,
#  'carácter legislativo': 44846,
#  'diario sesion': 111409,
#  'quedará constancia': 318930,
#  'incidencia producida': 192877,
#  'acta taquigráfica': 3306,
#  'manera precepto': 220418,
#  'directament aplic': 118120,
#  'práctica común': 311917,
#  'creo conoc': 82333,
#  'conoc derecho': 67085,
#  'derecho comparado': 106120,
#  'cualquier documento': 85030,
#  'haga precisament': 183618,
#  'precisament mayor': 291303,
#  'mayor solemnidad': 225529,
#  'mediant lectura': 226642,
#  'lectura cámara': 211987,
#  'perjuicio ulterior': 272872,
#  'cort si': 78668,
#  'si tema': 354997,
#  'tema éste': 379428,
#  'aplicado caso': 21098,
#  'caso saben': 46664,
#  'principio cómo': 299123,
#  'mediant seri': 226725,
#  'seri contacto': 351071,
#  'entiend presidencia': 137468,
#  'presidencia así': 294146,
#  'así manifiesta': 29230,
#  'propio pleno': 307911,
#  'resolución hecho': 337399,
#  'cumpl requisito': 88871,
#  'consta artículo': 70927,
#  'presi dent': 294107,
#  'formación política': 166915,
#  'política representación': 284451,
#  'formado part': 166974,
#  'desea uso': 108344,
#  'uso pausa': 397464,
#  'marco vizcaya': 222800,
#  'nombr minoría': 250599,
#  'minoría vasca': 236190,
#  'maciá alavedra': 218899,
#  'afectuoso saludo': 11216,
#  'cámara nuevo': 91594,
#  'legislatura así': 213000,
#  'así deseo': 28847,
#  'deseo toda': 108790,
#  'toda clase': 384448,
#  'difícil misión': 115817,
#  'saludo nombr': 345560,
#  'nombr propio': 250635,
#  'propio minoría': 307858,
#  'coalición democrática': 56036,
#  'democrática quiero': 104229,
#  'quiero recordar': 321097,
#  'hablo ahora': 180631,
#  'alianza popular': 16379,
#  'popular participación': 287185,
#  'permanent intervención': 272984,
#  'intervención breve': 203368,
#  'rendición cuenta': 335201,
#  'cuenta hecho': 86920,
#  'hecho cámara': 184444,
#  'cámara dicha': 91099,
#  'cuenta ocurrido': 87042,
#  'ocurrido allí': 257499,
#  'sido planteado': 356182,
#  'planteado part': 278814,
#  'part forma': 264837,
#  'quiero aprovechar': 320756,
#  'aprovechar momento': 23273,
#  'momento reiterar': 241769,
#  'da forma': 92976,
#  'forma dicho': 166136,
#  'dicho cuerpo': 113029,
#  'extraordinario cámara': 158513,
#  'cámara momento': 91554,
#  'momento decisivo': 240862,
#  'decisivo historia': 99369,
#  'historia legislativa': 186351,
#  'dicho quiero': 113634,
#  'quiero manifestar': 320975,
#  'actuó correctament': 5468,
#  'naturaleza proyecto': 246451,
#  'ahora cuenta': 13150,
#  'cort proyecto': 78659,
#  'proyecto asunto': 310315,
#  'asunto tan': 28412,
#  'tan important': 376892,
#  'toda necesidad': 384857,
#  'incluso carácter': 193196,
#  'carácter urbanístico': 45000,
#  'entro tema': 138731,
#  'debat diputación': 95561,
#  'norma relación': 251133,
#  'relación seguridad': 334350,
#  'seguridad ciudadana': 348606,
#  'asunto problema': 28351,
#  'problema part': 301647,
#  'duda alguna': 122711,
#  'número artículo': 253527,
#  'artículo cuanto': 25609,
#  'cuanto dice': 85627,
#  'podrán afectar': 282258,
#  'afectar derecho': 11171,
#  'derecho deber': 106220,
#  'deber libertad': 97930,
#  'libertad ciudadano': 213968,
#  'ciudadano regulado': 53946,
#  'regulado título': 332998,
#  'seguimo creyendo': 347981,
#  'inconstitucion part': 193832,
#  'part acuerdo': 264268,
#  'acuerdo cuanto': 5872,
#  'fon do': 165348,
#  'sido recordado': 356307,
#  'pleno cámara': 280180,
#  'cámara noviembr': 91592,
#  'hicimo constar': 185999,
#  'público necesaria': 318246,
#  'necesaria medida': 246972,
#  'medida adecuada': 226871,
#  'adecuada gravedad': 7264,
#  'gravedad situación': 177637,
#  'situación situación': 362859,
#  'despué duda': 109384,
#  'necesa rio': 246771,
#  'recordar aquello': 327201,
#  'medida suficient': 228056,
#  'proteg seguridad': 309767,
#  'seguridad ciudadano': 348607,
#  'crimin atentado': 83317,
#  'doña pilar': 122574,
#  'ejemplo puesto': 128880,
#  'cuenta tema': 87272,
#  'según informacion': 349486,
#  'publicado prensa': 312735,
#  'prensa nacion': 291936,
#  'nacion juez': 245398,
#  'juez instruy': 207982,
#  'parec dejar': 262734,
#  'ciudad si': 53144,
#  'si ésta': 355190,
#  'ésta situación': 409158,
#  'acción judici': 2282,
#  'ciudadano evidentement': 53558,
#  'evidentement tema': 153695,
#  'tema opin': 379021,
#  'creo hecho': 82654,
#  'hecho acabo': 184099,
#  'acabo mencionar': 1600,
#  'dicha medida': 112706,
#  'insuficient mismo': 200419,
#  'mismo esperar': 237536,
#  'tam bién': 376186,
#  'venga proyecto': 401181,
#  'proyecto ciertament': 310400,
#  'aquella medida': 23784,
#  'medida sino': 228033,
#  'situación límite': 362547,
#  'límite materia': 218152,
#  'materia seguridad': 224429,
#  'ciudadana público': 53217,
#  'público pue': 318436,
#  'pue encontramo': 313178,
#  'cuanto fondo': 85723,
#  'fondo si': 165776,
#  'si acaso': 352787,
#  'medida part': 227721,
#  'artículo constitución': 25571,
#  'tramitado proyecto': 389506,
#  'proyecto desgraciadament': 310640,
#  'suficient ello': 371758,
#  'ello entiendo': 131053,
#  'entiendo toda': 137724,
#  'toda razon': 385008,
#  'razon dicho': 322903,
#  'dicho proyecto': 113606,
#  'presentado cuanto': 293335,
#  'cuanto cámara': 85592,
#  'cámara terminar': 92107,
#  'dando cumplimiento': 93810,
#  'constitución así': 71653,
#  'así dando': 28767,
#  'cum plimiento': 88740,
#  'causa dificultad': 47968,
#  'dificultad funcionamiento': 115442,
#  'funcionamiento adecuado': 168937,
#  'adecuado dicho': 7412,
#  'dicho apart': 112847,
#  'part pleno': 265243,
#  'quiero añadir': 320767,
#  'necesidad urgent': 248251,
#  'urgent reforma': 397174,
#  'reforma reglamento': 331621,
#  'reglamento hecho': 332449,
#  'hecho período': 185106,
#  'período previo': 275760,
#  'previo eleccion': 297831,
#  'eleccion general': 129722,
#  'general hecho': 174769,
#  'hecho prisa': 185187,
#  'quizá excesiva': 321688,
#  'disposicion reglamento': 120066,
#  'hecho momento': 184969,
#  'momento circunstancia': 240681,
#  'circunstancia diferent': 52614,
#  'entiendo comisión': 137564,
#  'comisión reglamento': 58679,
#  'preparación específica': 292387,
#  'específica adecuada': 146865,
#  'tiempo necesario': 383021,
#  'necesario trabajo': 247640,
#  'trabajo important': 388483,
#  'important finalment': 190808,
#  'divid part': 121414,
#  'tema duda': 378695,
#  'duda present': 123096,
#  'present momento': 292725,
#  'momento supuesto': 241915,
#  'supuesto fondo': 373783,
#  'vaya allá': 400089,
#  'allá tiempo': 16573,
#  'vacacion verano': 398100,
#  'estrictament necesario': 150020,
#  'incluso contradiccion': 193226,
#  'vuelvo cuestión': 407253,
#  'dictando norma': 114544,
#  'norma supuesto': 251164,
#  'arreglo artículo': 25151,
#  'artículo facultad': 25787,
#  'momento asunto': 240572,
#  'asunto important': 28259,
#  'celebración pleno': 48395,
#  'pleno important': 280228,
#  'important cámara': 190582,
#  'pedido sido': 269927,
#  'sido tradición': 356509,
#  'tradición cámara': 389075,
#  'cámara presidencia': 91772,
#  'presidencia anterior': 294138,
#  'anterior toda': 19550,
#  'razon pedimo': 323148,
#  'reglamento cuanto': 332402,
#  'dentro desarrollo': 105085,
#  'sólo defensa': 374960,
#  'defensa gener': 101512,
#  'gener facultad': 173832,
#  'facultad corresponden': 158964,
#  'corresponden cámara': 78108,
#  'cámara sino': 92047,
#  'específicament artículo': 146966,
#  'produzca cuanto': 305083,
#  'solé tura': 369556,
#  'socialista present': 366279,
#  'present cámara': 292638,
#  'función oposición': 169756,
#  'funcion constitucional': 168653,
#  'congreso quisiera': 66367,
#  'quisiera felicitar': 321426,
#  'legislatura cámara': 213046,
#  'cámara actuación': 90671,
#  'actuación socialista': 4725,
#  'socialista momento': 366028,
#  'momento visto': 242042,
#  'servicio toda': 352092,
#  'toda cámara': 384535,
#  'cámara quisiera': 91868,
#  'quisiera entrar': 321417,
#  'entrar fondo': 138540,
#  'fondo asunto': 165389,
#  'presidencia anunciado': 294140,
#  'aquello portavoc': 24174,
#  'portavoc intervenido': 287988,
#  'intervenido anterioridad': 204007,
#  'posicion ideológica': 289672,
#  'ideológica política': 188446,
#  'política distinta': 283619,
#  'distinta socialista': 120749,
#  'socialista coincidido': 365199,
#  'respeto derecho': 338769,
#  'derecho principio': 106699,
#  'principio general': 299250,
#  'general ordenamiento': 174847,
#  'ordenamiento jurídico': 260048,
#  'simplement puesto': 358918,
#  'refier reglamento': 330605,
#  'reproducción artículo': 336677,
#  'artículo trata': 26374,
#  'cort sino': 78669,
#  'sino habla': 359960,
#  'finalment señalar': 162685,
#  'señalar elemento': 352662,
#  'tome nota': 385876,
#  'nota ello': 251588,
#  'ello ejemplo': 131034,
#  'texto distinto': 382010,
#  'cort diciembr': 78629,
#  'diciembr dice': 113956,
#  'conformidad establecido': 65961,
#  'establecido artículo': 148755,
#  'artículo vigent': 26422,
#  'vigent reglamento': 404738,
#  'reglamento provision': 332501,
#  'publicación boletín': 312683,
#  'cort congreso': 78617,
#  'congreso texto': 66416,
#  'texto norma': 382132,
#  'norma desarrollo': 250913,
#  'reglamento cort': 332398,
#  'pueden comprend': 314592,
#  'comprend ss': 61269,
#  'ss razon': 370532,
#  'afect seguridad': 10649,
#  'jurídica ahora': 208882,
#  'explicar socialista': 157002,
#  'socialista relación': 366474,
#  'correcta formulación': 77669,
#  'fin cuenta': 161645,
#  'permanent travé': 273057,
#  'travé procedimiento': 392495,
#  'hace minuto': 181225,
#  'verdad conocimiento': 402371,
#  'producir caso': 304441,
#  'caso tema': 46778,
#  'tema tan': 379333,
#  'important próximo': 191239,
#  'próximo debat': 312448,
#  'debat investidura': 95757,
#  'investidura socialista': 205572,
#  'socialista entendemo': 365539,
#  'entendemo debe': 136815,
#  'debe producirs': 97162,
#  'manera ahora': 219895,
#  'reflexion relación': 330910,
#  'relación funcionamiento': 334045,
#  'cuanto problema': 85959,
#  'problema jurídico': 301462,
#  'planteado problema': 278828,
#  'ejemplo manera': 128731,
#  'manera important': 220220,
#  'important naturaleza': 191038,
#  'naturaleza jurídica': 246417,
#  'entendemo forma': 136857,
#  'forma producido': 166536,
#  'alguna forma': 15768,
#  'forma procedimiento': 166532,
#  'procedimiento desarrollo': 302596,
#  'incluso modificar': 193426,
#  'sino número': 360204,
#  'relación aprobado': 333753,
#  'supongo cámara': 373257,
#  'cámara futuro': 91298,
#  'futuro justicia': 171055,
#  'justicia gustaría': 209683,
#  'cara futuro': 43833,
#  'futuro seguro': 171237,
#  'absolutament inoportuna': 968,
#  'ministerio interior': 235436,
#  'interior justicia': 201917,
#  'justicia rumor': 209911,
#  'rumor queremo': 343371,
#  'queremo señalar': 319410,
#  'entendemo interpretación': 136879,
#  'interpretación socialista': 203126,
#  'permanent relación': 273029,
#  'relación ésta': 334441,
#  'toda facultad': 384667,
#  'cámara cuanto': 90989,
#  'cuanto control': 85565,
#  'varia ocasion': 399563,
#  'ocasion algún': 256551,
#  'algún concreto': 16168,
#  'hizo si': 186785,
#  'intención propon': 200896,
#  'propon tramitación': 308223,
#  'tramitación proyecto': 389457,
#  'interpretación part': 203104,
#  'part única': 265664,
#  'única posibl': 410881,
#  'posibl aunqu': 288830,
#  'aunqu hizo': 31368,
#  'hizo cuanto': 186635,
#  'pudo evitar': 313002,
#  'tramitación decretosley': 389380,
#  'disolución cort': 119791,
#  'constitución quisiera': 72073,
#  'quisiera señalar': 321512,
#  'señalar cuanto': 352641,
#  'cuanto tema': 86098,
#  'tema fondo': 378788,
#  'fondo debería': 165472,
#  'debería producirs': 98179,
#  'producirs mayor': 304577,
#  'mayor rapidez': 225439,
#  'part servicio': 265500,
#  'servicio correspondient': 351610,
#  'correspondient ministerio': 78317,
#  'ministerio presidencia': 235539,
#  'presidencia ordenar': 294319,
#  'ofici acuerdo': 257770,
#  'acuerdo diputación': 5966,
#  'permanent materia': 272992,
#  'materia asunto': 223789,
#  'asunto baladí': 28135,
#  'baladí sino': 36191,
#  'sino precisament': 360328,
#  'supon acto': 372797,
#  'important acto': 190294,
#  'jurídica efecto': 208937,
#  'efecto toda': 127669,
#  'toda ss': 385100,
#  'ss saben': 370571,
#  'norma boletín': 250840,
#  'present aquella': 292593,
#  'vicepresident respuesta': 403564,
#  'explicación despué': 156733,
#  'despué haciendo': 109460,
#  'haciendo gestion': 183107,
#  'alguna persona': 15880,
#  'persona unión': 275286,
#  'unión centro': 396685,
#  'centro democrático': 48957,
#  'cierta influencia': 51100,
#  'mese despué': 232776,
#  'despué habers': 109450,
#  'habers aprobado': 178938,
#  'aprobado decretosley': 22736,
#  'debían haber': 98538,
#  'haber sido': 178837,
#  'sido tratado': 356526,
#  'permanent tema': 273050,
#  'tema candent': 378477,
#  'important refiero': 191295,
#  'refiero concreto': 330742,
#  'concreto tema': 64647,
#  'metro barcelona': 233165,
#  'objetor conciencia': 255413,
#  'conciencia socialista': 63718,
#  'socialista intentamo': 365834,
#  'dieran explicacion': 114634,
#  'explicacion pertinent': 156693,
#  'entonc sólo': 138076,
#  'sólo interior': 375159,
#  'respuesta planteamiento': 340300,
#  'planteamiento oposición': 279004,
#  'oposición ve': 259852,
#  'tema tal': 379330,
#  'tal importancia': 375863,
#  'quisiera salir': 321507,
#  'salir paso': 345280,
#  'práctica viciosa': 312114,
#  'juicio entonc': 208105,
#  'consejo aprobó': 69022,
#  'general luego': 174798,
#  'desarrollado posteriorment': 107402,
#  'posteriorment comisión': 290160,
#  'comisión experto': 58353,
#  'aquello parecía': 24149,
#  'constitución dar': 71745,
#  'facultad da': 158967,
#  'da ningún': 93035,
#  'ningún experto': 249767,
#  'responsabilidad aquel': 339517,
#  'aquel entonc': 23572,
#  'entonc secretario': 138045,
#  'secretario información': 346944,
#  'aquello pue': 24205,
#  'pue portavoz': 313374,
#  'según decía': 349401,
#  'decía nota': 100294,
#  'europa press': 151347,
#  'informó consejo': 197028,
#  'referent medida': 329855,
#  'medida seguridad': 228009,
#  'acuerdo básico': 5713,
#  'dicho consejo': 112986,
#  'consejo necesario': 69263,
#  'necesario comisión': 247226,
#  'comisión alto': 58102,
#  'alto cargo': 17166,
#  'cargo ministerio': 44263,
#  'determinada prevision': 110624,
#  'jurídica mismo': 208996,
#  'despué consejo': 109307,
#  'consejo enero': 69147,
#  'quiero insistir': 320949,
#  'deben producir': 97787,
#  'embargo siguen': 132148,
#  'siguen produciendo': 358388,
#  'exactament mismo': 154228,
#  'mismo sucedido': 238126,
#  'elección alcald': 129795,
#  'aprueba comisión': 23416,
#  'comisión subsecretario': 58749,
#  'publica boletín': 312668,
#  'aprobado comisión': 22711,
#  'subsecretario consejo': 371108,
#  'digo fecha': 116546,
#  'fecha anterior': 160458,
#  'anterior aprobación': 19022,
#  'creo práctica': 82989,
#  'pusieron reliev': 315984,
#  'reliev debat': 334967,
#  'funcionamiento normal': 169078,
#  'sometido derecho': 369721,
#  'derecho según': 106824,
#  'según establec': 349447,
#  'establec constitución': 148192,
#  'viola artículo': 405123,
#  'constitución cuanto': 71729,
#  'reserva legal': 337104,
#  'derecho fundamental': 106386,
#  'fundamental important': 170351,
#  'important puesto': 191248,
#  'puesto tema': 315789,
#  'establec ejercicio': 148276,
#  'ejercicio potestad': 129303,
#  'potestad jurisdiccion': 290421,
#  'tipo proceso': 384007,
#  'juzgando haciendo': 210303,
#  'haciendo ejecutar': 183072,
#  ...}

# %%
sum_words = bow.sum(axis=0) 
words_freq = [(word, sum_words[0, idx]) for word, idx in vect.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1])
vocabulary, _ = zip(*words_freq[:int(total_features * 0.75)])
less_vocabulary = list(vocabulary)

# %%
# Este es el listado del 75% de los bigramas con menor frecuencia
less_vocabulary
# Out:
# ['preparatoria procederá',
#  'dar jectura',
#  'jectura convocatoria',
#  'convocatoria lista',
#  'referent acto',
#  'poujad según',
#  'relación ta',
#  'ta secretaría',
#  'edad telesforo',
#  'urruela ruego',
#  'ruego monzón',
#  'monzón si',
#  'sala ocup',
#  'present monzón',
#  'monzón edad',
#  'edad rafael',
#  'present portanet',
#  'suárez lista',
#  'lista león',
#  'valverd ruego',
#  'valverd si',
#  'sala pase',
#  'valverd ocupa',
#  'siguiendo ruego',
#  'ruego esperabé',
#  'arteaga tome',
#  'posesión vicepresidencia',
#  'ruego diego',
#  'espejo jesú',
#  'lópez ramón',
#  'ramón varez',
#  'varez miranda',
#  'garcía ocupen',
#  'puesto respectivo',
#  'respectivo mesa',
#  'edad esperabé',
#  'esperabé artega',
#  'artega gonzález',
#  'espejo ocupan',
#  'vicepresidencia pérez',
#  'garcía secretaría',
#  'secretaría provision',
#  'provision rodríguez',
#  'valverd nombr',
#  'edad dirijo',
#  'profundo saludo',
#  'saludo desear',
#  'ánimo cumplamo',
#  'cumplamo alta',
#  'pueblo conferido',
#  'conferido perdonen',
#  'ss sentarm',
#  'sillón venga',
#  'venga recuerdo',
#  'recuerdo insign',
#  'insign fi',
#  'gura socialista',
#  'español ocupó',
#  'ocupó cort',
#  'constituyen obrero',
#  'obrero intelectu',
#  'pude contemplar',
#  'contemplar rectitud',
#  'rectitud justeza',
#  'justeza intervencion',
#  'cámara obrero',
#  'manual socialista',
#  'forma efímera',
#  'efímera ocupa',
#  'sillón mismo',
#  'rija verdaderament',
#  'aplauso propon',
#  'reanudar pensamo',
#  'debiera suspenders',
#  'suspenders momento',
#  'momento reanudarla',
#  'reanudarla dentro',
#  'presenten mesa',
#  'reanudars procedería',
#  'procedería dar',
#  'relación cumplido',
#  'cumplido agilizar',
#  'agilizar propondría',
#  'propondría cámara',
#  'dieran leído',
#  'den leído',
#  'recurso escrutinio',
#  'podido presentars',
#  'dar elección',
#  'elección interino',
#  'interino secretario',
#  'secretario irá',
#  'lista alfabético',
#  'alfabético provincia',
#  'elegido pue',
#  'correspond interino',
#  'interino greso',
#  'greso secretario',
#  'terminado empieza',
#  'empieza escrutinio',
#  'escrutinio mitad',
#  'present landelino',
#  'alsina lui',
#  'llorent ignacio',
#  'bezar adolfo',
#  'martorel jaim',
#  'jaim castel',
#  'ferrer telesforo',
#  'urruela francisco',
#  'belzunc blanco',
#  'interina landelino',
#  'lavilla dado',
#  'propon suspenda',
#  'suspenda reanud',
#  'reanud media',
#  'interina advierto',
#  'escribirs nombr',
#  'necesario reparta',
#  'reparta papel',
#  'papeleta escaño',
#  'inmediatament atendido',
#  'atendido secretario',
#  'provision alvarez',
#  'garcía lee',
#  'terminada dar',
#  'poujad lui',
#  'llorent doña',
#  'fernándezlatorr ignacio',
#  'bezar llibert',
#  'llibert cuatrecas',
#  'membrado blanco',
#  'leído escrutinio',
#  'escrutinio frail',
#  'poujad gómez',
#  'llorent fernándezespaña',
#  'fernándezlatorr gallego',
#  'bezar pasamo',
#  'vuelv advertir',
#  'escrutinio escrutado',
#  'escrutado descomponen',
#  'forma víctor',
#  'felgueroso doña',
#  'rojo doña',
#  'doña so',
#  'so ledad',
#  'ledad becerril',
#  'bustamant leopoldo',
#  'boursault alfonso',
#  'márquez blanco',
#  'secretario carrasc',
#  'secretario izquierdo',
#  'tercero becerril',
#  'cuarto torr',
#  'boursault finalizado',
#  'ruega mesa',
#  'elegida interinament',
#  'interinament tome',
#  'alsina vicepresident',
#  'vicepresident modesto',
#  'modesto rail',
#  'rail poujud',
#  'poujud vicepresident',
#  'fernándezespaña vicepresident',
#  'cuarto igracio',
#  'igracio gallego',
#  'bezar secretario',
#  'secretario dun',
#  'dun víctor',
#  'cuarto leopoldo',
#  'buursault ruego',
#  'ruego suban',
#  'alsina modesto',
#  'poujad vicepresident',
#  'latorr vicepresident',
#  'bezar vicepresident',
#  'cuarto victor',
#  'victor carrasc',
#  'tercero leopoldo',
#  'forman mesa',
#  'interina congreso',
#  'congreso ocupan',
#  'puesto estrado',
#  'señoñoría convencionalismo',
#  'convencionalismo clase',
#  'brevement propio',
#  'interina agradecimiento',
#  'agradecimiento elección',
#  'elección acabái',
#  'acabái creo',
#  'expresar hacerm',
#  'eco piensa',
#  'piensa totalidad',
#  'agradecimiento mesa',
#  'presidido escrutinio',
#  'escrutinio gran',
#  'serenidad corrección',
#  'corrección cualquiera',
#  'mesa cualquiera',
#  'sido significación',
#  'interina conferido',
#  'conferido cámara',
#  'actuación perderemo',
#  'perderemo renegaremo',
#  'renegaremo perspectiva',
#  'institucion asumo',
#  'preocupación impon',
#  'impon percibir',
#  'presid falta',
#  'congreso cumplirá',
#  'tarea sintonía',
#  'sintonía pue',
#  'mento histórico',
#  'histórico exig',
#  'funcion reglamentariament',
#  'falta faltará',
#  'faltará voluntad',
#  'voluntad proclamo',
#  'proclamo actuar',
#  'ello aspiración',
#  'aspiración entiendo',
#  'congreso efectiva',
#  'protección puedamerec',
#  'puedamerec manten',
#  'manten consideración',
#  'consideración anima',
#  'homenaj afecto',
#  'admiración duda',
#  'comparten aplauso',
#  'dirigido alvarez',
#  'miranda quiero',
#  'destacar singular',
#  'singular dote',
#  'dote objetividad',
#  'objetividad cordialidad',
#  'tan supo',
#  'supo acreditar',
#  'acreditar recordado',
#  'conjunto diálogo',
#  'diálogo gobernant',
#  'gobernado diálogo',
#  'minoría contienden',
#  'contienden fundamento',
#  'oposición implica',
#  'constitucion equilibrar',
#  'equilibrar ponderar',
#  'ponderar criticar',
#  'criticar ofrec',
#  'ofrec eventual',
#  'eventual alternativa',
#  'compartir ejercicio',
#  'poder diálogo',
#  'asamblea necesariament',
#  'sosegado poner',
#  'especialment enriquecedor',
#  'enriquecedor futura',
#  'escenario articulars',
#  'articulars diálogo',
#  'próximo cort',
#  'convivencia expresión',
#  'expresión acabada',
#  'acabada constitución',
#  'partida ideal',
#  'ideal ausencia',
#  'ausencia dogmatismo',
#  'dogmatismo flexibilidad',
#  'flexibilidad tarea',
#  'futuro articulación',
#  'articulación aquello',
#  'aquello diálogo',
#  'serio fecundo',
#  'fecundo eficaz',
#  'eficacia fecundidad',
#  'fecundidad seriedad',
#  'seriedad depend',
#  'depend aprecio',
#  'aprecio pueblo',
#  'parlamento esforzarno',
#  'esforzarno mutuo',
#  'mutuo necesario',
#  'perjuicio fidelidad',
#  'fidelidad mismo',
#  'lograr sintonía',
#  'sintonía tarea',
#  'tarea aliento',
#  'aliento pueblo',
#  'español entenderá',
#  'vivo proyectada',
#  'proyectada diálogo',
#  'diálogo explayada',
#  'explayada parlamento',
#  'civilizada confrontar',
#  'posicion dirimir',
#  'hacemo contribuido',
#  'decisivament crear',
#  'derecho conquistar',
#  'conquistar consolidar',
#  'consolidar sino',
#  'agradecimiento ponerno',
#  'disposición recabar',
#  'colaboración expresar',
#  'sabrán asegurar',
#  'aplauso conformidad',
#  'reglamentario próxima',
#  'reglamentaria conciern',
#  'conciern dación',
#  'permanent asumió',
#  'transcurrido disolución',
#  'satisfac asimi',
#  'asimi comisión',
#  'incompatibilidad correspond',
#  'miembro previament',
#  'previament relativo',
#  'comunicacion presi',
#  'dencia consumir',
#  'consumir significando',
#  'significando ss',
#  'perfectament constituido',
#  'constituido pone',
#  'pone singularment',
#  'singularment reliev',
#  'incompatibilidad atrevería',
#  'ss procedieran',
#  'procedieran constitución',
#  'adecuacion puedan',
#  'reglamentaria quería',
#  'oficialment obligado',
#  'declaración notari',
#  'notari patrimonial',
#  'tercera estableció',
#  'declaracion mesa',
#  'regir formular',
#  'declaracion notarial',
#  'notarial refier',
#  'constitución interina',
#  'marzo permito',
#  'reglamentaria referido',
#  'seguidament tratar',
#  'cuanto dación',
#  'permanent funcionó',
#  'funcionó período',
#  'intersesion verano',
#  'entendido siendo',
#  'acto dación',
#  'cuenta consiguientement',
#  'consiguientement ningún',
#  'presidió diputación',
#  'ello complementariament',
#  'complementariament aquello',
#  'siguen cámara',
#  'asimismo expon',
#  'posterioridad dación',
#  'procederá abrir',
#  'digo formaron',
#  'agradec indicacion',
#  'extrañeza protesta',
#  'protesta paso',
#  'reglamentario dar',
#  'dar dación',
#  'referido dars',
#  'dars relación',
#  'incompatibilidad escrúpulo',
#  'escrúpulo tratado',
#  'cuenta publicación',
#  'reglamentaria provisional',
#  'costumbr estableció',
#  'materia cómputo',
#  'artículo dictada',
#  'dictada subsanar',
#  'publicada previament',
#  'previament boletín',
#  'cort mención',
#  'hace púbtico',
#  'púbtico dicen',
#  'publicacion gene',
#  'gene to',
#  'to ocupa',
#  'infracción important',
#  'reglamento infracción',
#  'atenerno probablement',
#  'probablement acto',
#  'pediría informas',
#  'informas aspecto',
#  'afectar distribuyan',
#  'distribuyan previament',
#  'mínimament reglamento',
#  'reglamento situa',
#  'ción inseguridad',
#  'jurídica proscrib',
#  'proscrib constitución',
#  'pecesbarba reglamento',
#  'prevé publicidad',
#  'reproducción ulterior',
#  'ulterior precedent',
#  'resolucion comunicada',
#  'objeto reproducción',
#  'producido sesion',
#  'legislativo reproducirán',
#  'reproducirán diario',
#  'producida sesion',
#  'secreta levantará',
#  'taquigráfica etc',
#  'común pecesbarba',
#  'comparado publicación',
#  'solemnidad mediant',
#  'saben premura',
#  'trabajado diticulitad',
#  'diticulitad reterido',
#  'reterido principio',
#  'tratando suplirlo',
#  'suplirlo mediant',
#  'enormement laboriosa',
#  'presidencia consiguientement',
#  'pleno publicación',
#  'publicación solemn',
#  'inici publicidad',
#  'publicidad perjuicio',
#  'reproducción literalment',
#  'literalment consta',
#  'cort pasar',
#  'pue dación',
#  'permanent fernando',
#  'miranda presi',
#  'representación formado',
#  'plazo minu',
#  'to marco',
#  'saludo cámara',
#  'breve entend',
#  'entend rendición',
#  'dicha dinutación',
#  'dinutación sido',
#  'perfecta objetiva',
#  'objetiva rendición',
#  'doblement breve',
#  'breve guno',
#  'tocar sido',
#  'forma coinciden',
#  'compañero opinado',
#  'opinado quiero',
#  'felicitación colectivament',
#  'colectivament dirigimo',
#  'dirigimo fernando',
#  'miranda da',
#  'cuerpo extraordinario',
#  'legislativa conducido',
#  'buen pul',
#  'pul so',
#  'so honestidad',
#  'honestidad probada',
#  'probada dicho',
#  'manifestar participamo',
#  'participamo diputación',
#  'permanent negativo',
#  'negativo junta',
#  'acuartelamiento entendemo',
#  'entendemo actuó',
#  'correctament diputación',
#  'mayoritario correspondía',
#  'correspondía naturaleza',
#  'proyecto estimo',
#  'estimo mismo',
#  'entonc alegó',
#  'alegó ahora',
#  'cuenta enviar',
#  'necesidad mencionaron',
#  'mencionaron incluso',
#  'urbanístico figuraban',
#  'figuraban clarament',
#  'clarament ex',
#  'ex puesta',
#  'legislación quería',
#  'prorrogar entro',
#  'tema natur',
#  'natur polémico',
#  'part tendíamo',
#  'tendíamo duda',
#  'alguna formalment',
#  'formalment constitucion',
#  'constitucion entraba',
#  'entraba prohibicion',
#  'prohibicion número',
#  'título seguimo',
#  'creyendo formalment',
#  'cuanto fon',
#  'preocupación serio',
#  'seguido agravándos',
#  'agravándos despué',
#  'duda necesa',
#  'ciudadano cobard',
#  'cobard lament',
#  'lament crimin',
#  'atentado dama',
#  'dama doña',
#  'pilar careaga',
#  'careaga hace',
#  'hace roteada',
#  'roteada espalda',
#  'modo vil',
#  'mencionado rendición',
#  'tema suplicatorio',
#  'suplicatorio audiencia',
#  'audiencia vitoria',
#  'vitoria según',
#  'instruy correspondient',
#  'protegida debidament',
#  'mencionar indican',
#  'indican lejo',
#  'lejo innecesaria',
#  'esperar tam',
#  'bién invita',
#  'invita pronto',
#  'ciertament derogar',
#  'sino ampliarla',
#  'ampliarla evitar',
#  'evitar lle',
#  'lle guemo',
#  'guemo mo',
#  'dilema acuerdo',
#  'acaso parecían',
#  'entendíamo formalment',
#  'formalment respetaba',
#  'respetaba artículo',
#  'causa propusieron',
#  'propusieron tramitado',
#  'proyecto poniéndolo',
#  'poniéndolo mejorando',
#  'dando cum',
#  'plimiento artículo',
#  'apart resistencia',
#  'resistencia injustificada',
#  'pleno cum',
#  'plimiento funcion',
#  'reglamentación lleva',
#  'plantearno dicho',
#  'añadir voz',
#  'voz necesidad',
#  'constituida designemo',
#  'designemo persona',
#  'apart preparación',
#  'adecuada dispongan',
#  'dicha re',
#  're slamentación',
#  'slamentación divid',
#  'urgent toqu',
#  'transcurra vacacion',
#  'verano estrictament',
#  'tanta laguna',
#  'laguna incluso',
#  'contradiccion reglamento',
#  'reglamento resuelta',
#  'resuelta constantement',
#  'constantement vuelvo',
#  'cuestión dictando',
#  'suplir dictar',
#  'important supongan',
#  'supongan realment',
#  'realment adicion',
#  'mera interpretacion',
#  'mismo supongan',
#  'supongan previsión',
#  'previsión celebración',
#  'cámara desear',
#  'desear dentro',
#  'necesario publicado',
#  'publicado antemano',
#  'antemano pedido',
#  'artículo indiscut',
#  'facultad expresament',
#  'expresament recordada',
#  'recordada sólo',
#  'artículo produzca',
#  'clara puntual',
#  'puntual reglamentación',
#  'saludar resto',
#  'resto indicarl',
#  'indicarl cumplimiento',
#  'oposición colaboraremo',
#  'colaboraremo funcion',
#  'establecida congreso',
#  'felicitar diputación',
#  'reiterar protesta',
#  'cuestión agradec',
#  'anterioridad pese',
#  'coincidido respeto',
#  'jurídico simplement',
#  'convencido interpretación',
#  'interpretación contestación',
#  'indicar reproducción',
#  'reproducción refier',
#  'sesion incidencia',
#  'producida pleno',
#  'trata boletín',
#  'publicación reproducción',
#  'reproducción quisiera',
#  'elemento alabado',
#  'alabado anterior',
#  'cort diario',
#  'distinto boletín',
#  'ordena publicación',
#  'congreso fernando',
#  'miranda pueden',
#  'razon afect',
#  'formulación fin',
#  'procedimiento enterado',
#  'guna reflexion',
#  'legislatura quisiéramo',
#  'quisiéramo dividir',
#  'dividir reflexion',
#  'jurídica decretosley',
#  'trabajo diputación',
#  'permanent inventado',
#  'inventado alguna',
#  'constitución convalidado',
#  'convierten consiguient',
#  'modificar numeración',
#  'numeración forma',
#  'forma iden',
#  'iden tificado',
#  'tificado sino',
#  'corresponda relación',
#  'nota desarrollarlo',
#  'desarrollarlo cara',
#  'mantendrá absolutament',
#  'inoportuna aunqu',
#  'provision unión',
#  'unión natura',
#  'natura ministerio',
#  'socialista di',
#  'di mo',
#  'mo funcionamiento',
#  'ésta asumía',
#  'facultad correspondían',
#  'correspondían cámara',
#  'decretosley asumida',
#  'asumida diputación',
#  'permanent varia',
#  'solicitó hizo',
#  'puso asumiendo',
#  'asumiendo interpretación',
#  'evitar prosperas',
#  'prosperas racionalidad',
#  'parar prosperó',
#  'prosperó interpretación',
#  'interpretación fundament',
#  'fundament diputación',
#  'permanent controla',
#  'controla tramitación',
#  'decretosley aplic',
#  'aplic disolución',
#  'teoría decretosley',
#  'convierten convalidado',
#  'convalidado supon',
#  'acto publicación',
#  'saben publicación',
#  'ofici permitimo',
#  'permitimo pedir',
#  'pedir explica',
#  'respuesta explicación',
#  'influencia boletín',
#  'ofici consiguió',
#  'consiguió publicas',
#  'publicas mese',
#  'tratado diputación',
#  'candent important',
#  'tema suceso',
#  'parla militarización',
#  'militarización metro',
#  'barcelona detención',
#  'detención objetor',
#  'introducir debatirlo',
#  'debatirlo aquella',
#  'pertinent entonc',
#  've interesado',
#  'parlamento versión',
#  'versión diputación',
#  'permanent tratas',
#  'señalado fin',
#  'fin observacion',
#  'observacion última',
#  'gravement inconstitucion',
#  'inconstitucion quisiera',
#  'viciosa juicio',
#  'denuncié consist',
#  'ciudadana literalidad',
#  'literalidad ja',
#  'ja terminología',
#  'terminología profesor',
#  'profesor carrió',
#  'carrió sino',
#  'información afirmaba',
#  'portavoz según',
#  'press interrogado',
#  'interrogado razón',
#  'ciudadana contestó',
#  'planteamiento decretosley',
#  'hicieran determinada',
#  'prevision jurídica',
#  'concluyeron despué',
#  'enero recibimo',
#  'recibimo allí',
#  'jurídica vicepresident',
#  'comprend convencieron',
#  'convencieron quiero',
#  'insistir práctica',
#  'sucedido elección',
#  'alcald composición',
#  'corporacion aprueba',
#  'subsecretario miércol',
#  'miércol publica',
#  'ofici indicando',
#  'indicando marzo',
#  'marzo habers',
#  'modesto publica',
#  'publica digo',
#  'constitución respetarla',
#  'respetarla seguridad',
#  'ciudadana anticonstitucion',
#  'limita decretosley',
#  'decretosley cuanto',
#  'desarrolla reserva',
#  'legal vara',
#  'vara derecho',
#  'establezcan vicioso',
#  'vicioso esperar',
#  'esperar convalidación',
#  'convalidación éste',
#  'vía torcida',
#  'torcida incorporar',
#  'razón glosa',
#  'glosa acción',
#  'necesariament terminar',
#  'solicitando derogación',
#  'subsanará posteriorment',
#  'pecesbarba falta',
#  'constitución formulación',
#  'proposición risa',
#  'pasamo rela',
#  'tivo constitución',
#  'misión reglamentariament',
#  'desarrollar período',
#  'conced integrar',
#  'integrar razón',
#  'elaborada previa',
#  'deliberación mesa',
#  'trasladar estrictament',
#  'coexistir integrado',
#  'integrado tomó',
#  'constitución comunista',
#  'comunista entrada',
#  'entrada recientement',
#  'escrito constituy',
#  'constituy conformidad',
#  'ruego distinta',
#  'resolución publicará',
#  'boletín mañana',
#  'posibl señalaría',
#  'señalaría veinticuatro',
#  'veinticuatro verifiquen',
#  'verifiquen comunicación',
#  'concreta encomendada',
#  'encomendada mismo',
#  'incompatibilidad hagan',
#  'funcion agotado',
#  'convocada saben',
#  'proced cum',
#  'plimiento dispuesto',
#  'requisito abrían',
#  'necesidad ce',
#  'ce lebrar',
#  'lebrar reunión',
#  'formulación majestad',
#  'rey conformidad',
#  'constitución disponibilidad',
#  'disponibilidad candidato',
#  'propuesto somet',
#  'somet programa',
#  'programa pleno',
#  'rey refrendada',
#  'refrendada greso',
#  'greso dice',
#  'excelentísimo adolfo',
#  'gonzález candidato',
#  'presidencia zarzuela',
#  'zarzuela marzo',
#  'marzo juan',
#  'carlo refrendado',
#  'alsina sabido',
#  'provision elaborado',
#  'anterioridad elaboración',
#  'resolución señalando',
#  'término proceders',
#  'proceders plenaria',
#  'plenaria efecto',
#  'cort ayer',
#  'marzo proced',
#  'aprovech eco',
#  'eco aún',
#  'resuena cámara',
#  'voluntad nombr',
#  'represento total',
#  'dictada acto',
#  'acto ruega',
#  'ruega someta',
#  'candidato presi',
#  'dencia propio',
#  'someters cuanto',
#  'cámara resisto',
#  'creer ocasión',
#  'solemn vivimo',
#  'vivimo tanta',
#  'pueblo digna',
#  'profundidad hurt',
#  'amplia confrontación',
#  'política revelado',
#  'revelado término',
#  'numérico cámara',
#  'cámara división',
#  'rígida posicion',
#  'inflex obligado',
#  'tener ejercitar',
#  'ejercitar fa',
#  'cultad reglamentariament',
#  'corresponden adoptar',
#  'solución procedent',
#  'izquierda conform',
#  'reglamento vacío',
#  'vacío deben',
#  'deben suplido',
#  'suplido congreso',
#  'congreso notoria',
#  'notoria existencia',
#  'desarrollars existencia',
#  'vacío procedencia',
#  'procedencia hiciera',
#  'artículo llenarlo',
#  'llenarlo implícita',
#  'implícita conversacion',
#  'conversacion individualment',
#  'individualment renresentant',
#  'renresentant distinto',
#  'conjunta asumido',
#  'propia respcnsabilidad',
#  'respcnsabilidad correspond',
#  'facultad término',
#  'parec admitida',
#  'admitida existencia',
#  'complementaria consiguient',
#  'posibilidad procedencia',
#  'procedencia presidencia',
#  'presidencia llenara',
#  'llenara vacío',
#  'vacío conformidad',
#  'parec alc',
#  'alc discrepancia',
#  'trate formalizarla',
#  'formalizarla función',
#  'función satisfactorio',
#  'entendiendo cuestión',
#  'planteada referencia',
#  'adoptada entiend',
#  'consecuencia preced',
#  'reglamento acatada',
#  'acatada cámara',
#  'banco vote',
#  'supon invocación',
#  'consecuencia carrillo',
#  'reglamento citando',
#  'aplicación reclam',
#  'reclam carrillo',
#  'carrillo solicita',
#  'presidencia co',
#  'rrespond conform',
#  'resolv interpretación',
#  'rumor fijación',
#  'dictada suplir',
#  'existent reglamento',
#  'permiten respecto',
#  'establec alterado',
#  'iniciativa cincuenta',
#  'cincuenta precepto',
#  'conexión párrafo',
#  'señala pleno',
#  'comision fijado',
#  'trata fijado',
#  'presidencia concreción',
#  'concreción disposición',
#  'éste ocurrió',
#  'último confección',
#  'confección requería',
#  'fijado reglamentariament',
#  'reglamentariament requier',
#  'fijado constitucionalment',
#  'formula interpretación',
#  'interpretación invocando',
#  'cabe motivo',
#  'alguno debiendo',
#  'debiendo aca',
#  'aca tars',
#  'tars resolución',
#  'carrillo rumoré',
#  'rumoré debat',
#  'acaba plantears',
#  'cabrá debat',
#  'debiendo acatars',
#  'acatars resolución',
#  'carrillo rectificar',
#  'rectificar rumor',
#  'carrillo reunión',
#  'consultó confrontación',
#  'término desarrollars',
#  'desarrollars debía',
#  'dictar presidencia',
#  'carrillo planteó',
#  'supon fi',
#  'jación tema',
#  'someten ple',
#  'ple vien',
#  'respecto acatamiento',
#  'part abdicación',
#  'abdicación re',
#  'ponsabilidad presidencia',
#  'presidencia correspondía',
#  'correspondía recuerda',
#  'recuerda posicion',
#  'posicion produjeron',
#  'produjeron pre',
#  'sident recabó',
#  'recabó responsabilidad',
#  'responsabilidad deter',
#  'minó adoptaría',
#  'adoptaría resolución',
#  'resolución estimara',
#  'estimara procedent',
#  'dent conscient',
#  'importancia proceda',
#  'proceda buen',
#  'buen cuestion',
#  'cuestion side',
#  'side planteada',
#  'planteada venia',
#  'entend facultad',
#  'suplir caso',
#  'reglamento discutida',
#  'cámara oplnión',
#  'oplnión person',
#  'errónea artículo',
#  'invocada texto',
#  'cuestion polí',
#  'tica fondo',
#  'recordado clima',
#  'empezado completament',
#  'tal rompimiento',
#  'rompimiento uso',
#  'cámara dueña',
#  'dueña momento',
#  'cambiarlo totalidad',
#  'prescripcion reglamen',
#  'to trate',
#  'trate disposición',
#  'nueva emanada',
#  'emanada mesa',
#  'mesa discutirla',
#  'opinión pronuncio',
#  'pronuncio mocion',
#  'discut planteamiento',
#  'planteamiento variación',
#  'variación duda',
#  'permitía pedir',
#  'puesta vote',
#  'vote sabremo',
#  'sabremo quier',
#  'reglamento vario',
#  'vario plauso',
#  'cámara promulgan',
#  'promulgan propio',
#  'previsión nive',
#  'nive constitucion',
#  'configurar potestad',
#  'posibilidad exclusividad',
#  'exclusividad cámara',
#  'constitucion previsión',
#  'política determinó',
#  'determinó fundamento',
#  'dars facultad',
#  'normativa facultad',
#  'reglamentaria dars',
#  'potestad autonormación',
#  'autonormación potestad',
#  'potestad dars',
#  'interna correspond',
#  'omision detecten',
#  'detecten vía',
#  'distinta complementar',
#  'competencia pareja',
#  'pareja figura',
#  'habitu reglamento',
#  'cámara lguno',
#  'lguno vote',
#  'vote solventada',
#  'solventada cuestion',
#  'cuestion proseguir',
#  ...]

# %%
print(f"De los {total_features} de bigramas totales se identifican los {len(less_vocabulary)} con menor frecuencia.")
# Out:
# De los 8228192 de bigramas totales se identifican los 6171144 con menor frecuencia.

# %%
voc=vect.vocabulary_.keys()-less_vocabulary-top_vect.vocabulary_.keys()

# %%
len(voc)
# Out:
# 1645639

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv=TfidfVectorizer(ngram_range=[2,2], vocabulary=voc)
vec = cv.fit(base['tokens'])

# %%
matrix = vec.transform(base['tokens'])

# %%
matrix.shape
# Out:
# (334421, 1645639)

# %% [markdown]
# # LDA con 10 clusters

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Acá hay un problema porque se sigue usando 10 clusters cuando en realidad habría que chequear el número óptimo de clusters una vez definida la cantidad de bigramas a utilizar
lda = LatentDirichletAllocation(n_components=10, max_iter=5, learning_method='online', learning_offset=50.,random_state=0)

# %%
# Esta celda en 1.6M parámetros tarda casi 4 horas en correr
lda.fit(matrix)
# Out:
# LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                           max_iter=5, random_state=0)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx + 1))
        print(" , ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lda, feature_names=cv.get_feature_names_out(), no_top_words=20)
# Out:
# Topic 1:
# ruizherrera confeder , juliá popular , marea expósito , popular valmaña , marea pita , agirretxea terminar , ciudadano salvador , domènech adelant , galván confeder , marea honorato , mismo borrà , republicano eritja , hera convergència , bosch terminar , pública alberto , campuzano vasco , agirretxea popular , jordà errekondo , jordà fernández , sostr unión
# Topic 2:
# fernández ahora , pleno citado , social rafael , presentada vota , votacion expedient , díez contestar , salga hemiciclo , ruego oye , virtud cediel , posicionars relación , urgencia levanta , perdón vicepresidenta , valora efecto , popular arriba , esteban candidato , hablar salga , secretario escribirá , anchuelo ruego , vayan continú , totalidad iu
# Topic 3:
# coma adelant , quevedo transaccion , socialista galovart , moscoso popular , marea representación , davila pérez , tardà fernández , paliar preocupant , marea botejara , estev adelant , crimin fortalecimiento , socialista bellido , macia fijación , sicilia popular , díez acabó , apartado dieciocho , hurtado terminar , pigem fijar , vidal ministra , pregunto fernández
# Topic 4:
# montero adelant , plural castaño , posicion martínez , telechea ciudadano , mismo sorlí , socialista botella , sayó socialista , mixto postiu , popular borrego , picó campuzano , popular píriz , votacion reforma , segura terminar , valentí vasco , nombrado proced , proyecto precursor , álvarez mismo , xuclà ciudadano , calvent gallego , intervien bel
# Topic 5:
# montserrat adelant , marea garcía , legarda adelant , popular dueña , campuzano bloqu , mismo matut , canadé mixto , teresa angulo , sanz convergència , muchísima representación , sumelzo socialista , tardà finalizar , barberà fijación , formula aitor , garcía confeder , ruiz mixto , moya catalán , décima tercera , fijará martínez , fernández terminar
# Topic 6:
# armendáriz mixto , jordà mixto , popular alberto , díaz confeder , cooperación josé , diputada llamo , ciudadano quinto , sanción abandono , ciclomotor sanción , herick campo , casado ciudadano , representant confeder , jiménez popular , financiera presentar , personal garantía , interior carlo , funcion agricultura , sufragio toda , democracia formula , quinta relativo
# Topic 7:
# marea lópez , accensi vasco , ciudadano cantó , buldó vasco , marea delgado , socialista cancela , moné ciudadano , reina popular , pública francesc , tardà ciudadano , utilización popular , davila bosch , pública miguel , igualdad josé , ciuró vasco , joan roda , representación confeder , popular ruano , interior miguel , popular estel
# Topic 8:
# barreda formulada , transitoria relativo , posicion salvador , pezzi socialista , mismo xuclà , marea vasco , relación acercamiento , apartado doce , pérezcastejón socialista , rivera candidato , rodríguez terminar , turismo presentación , seccion empleo , negociando transaccion , relativa potenciar , dictamen ingreso , gordo ministra , independencia informativa , septiembr modifica , toda delegación
# Topic 9:
# permanent mixto , marea sixto , vox abasc , marea yllane , marea alba , gorriarán convergència , rivera confeder , alférez socialista , aguilar terminar , interior gabriel , pérez terminar , rocío cuello , mismo vendrel , formula cayo , dirigida alfredo , larreina izquierda , socialista urquizu , socialista cantera , gonzálezmoro mixto , común iglesia
# Topic 10:
# castañón confeder , republicano bassa , pérez confeder , mismo miquel , calduch catalán , popular angulo , montón fijación , marea vera , gómezreino adelant , fundacion anexo , marea ramo , general fijación , echániz adelant , merino formulada , eajpnv agirretxea , realización dictamen , castillo popular , orama pérez , llaguno confeder , martínez iu

# %%
lda.components_.shape
# Out:
# (10, 1645639)

# %% [markdown]
# # Weights y Frex

# %%
import scipy as sp
from scipy.special import logsumexp
import numpy as np

# %%
def frex(mod, w=0.7):
    log_beta = np.log(mod.components_)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    out = 1. / (w / exclusivity_ecdf + (1 - w) / freq_ecdf)
    return out

# %%
def ecdf(arr):
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
frex_df=pd.DataFrame(frex(lda))
frex_df
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.171230  0.585171  0.077409  0.999297  0.249853  0.274329  0.013673
# 1  0.024161  0.484886  0.077337  0.027343  0.217952  0.273374  0.013612
# 2  0.020799  0.422276  0.076495  0.026999  0.211156  0.272315  0.999464
# 3  0.708857  0.564315  0.072967  0.025103  0.231517  0.268180  0.012448
# 4  0.162381  0.345657  0.077036  0.027237  0.165210  0.273475  0.013550
# 5  0.785185  0.489497  0.998263  0.027087  0.227911  0.996799  0.013440
# 6  0.678810  0.423871  0.054204  0.018034  0.153155  0.172596  0.009542
# 7  0.117742  0.652261  0.041585  0.014030  0.896500  0.094655  0.008704
# 8  0.595718  0.516664  0.077850  0.027582  0.199894  0.272439  0.013647
# 9  0.026584  0.458413  0.077985  0.027554  0.195190  0.275020  0.013847
#
#      7         8         9       ...    163017    163018    163019    163020  \
# 0  0.051542  0.008938  0.053714  ...  0.461637  0.233950  0.835446  0.307373
# 1  0.051398  0.008781  0.053766  ...  0.456411  0.626283  0.319778  0.332898
# 2  0.050865  0.008651  0.053185  ...  0.473560  0.189224  0.782424  0.288076
# 3  0.047996  0.007927  0.050409  ...  0.366201  0.380166  0.767079  0.259369
# 4  0.051601  0.008791  0.053670  ...  0.409857  0.760319  0.769518  0.306313
# 5  0.051363  0.999647  0.053777  ...  0.465718  0.478704  0.624102  0.338549
# 6  0.990765  0.005613  0.038111  ...  0.319239  0.571007  0.553509  0.216207
# 7  0.027761  0.005410  0.984303  ...  0.718512  0.432401  0.494855  0.848579
# 8  0.051761  0.008877  0.054178  ...  0.341284  0.127920  0.661391  0.340978
# 9  0.051994  0.009009  0.054574  ...  0.429470  0.365502  0.774173  0.341639
#
#      163021    163022    163023    163024    163025    163026
# 0  0.348187  0.510595  0.395070  0.650024  0.585421  0.321454
# 1  0.360416  0.308161  0.406895  0.526527  0.685021  0.385255
# 2  0.344615  0.335994  0.346888  0.714253  0.570337  0.766381
# 3  0.357870  0.212334  0.255546  0.366330  0.541776  0.752601
# 4  0.337970  0.509110  0.324131  0.689538  0.543385  0.438488
# 5  0.330361  0.409281  0.296974  0.659329  0.610730  0.346462
# 6  0.249478  0.215461  0.885974  0.522337  0.785272  0.525566
# 7  0.829356  0.744339  0.157597  0.543039  0.269374  0.452022
# 8  0.255600  0.302783  0.216389  0.572428  0.702511  0.187727
# 9  0.326357  0.427706  0.312967  0.690742  0.637317  0.395438
#
# [10 rows x 163027 columns]

# %%
no_top_words=10
feature_names=vec.get_feature_names_out()
for topic_idx, topic in enumerate(frex(lda)):
        print("Topic %d:" % (topic_idx + 1))
        print(" , ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
# Out:
# Topic 1:
# podemosen comú , podemen marea , comú podemen , unido podemosen , confeder unido , ministra adelant , acabado tiempo , diputada terminar , ministra defensa , adelant ministra
# Topic 2:
# catalunya verd , posicion mixto , doña maría , rodríguez zapatero , celebración extraordinaria , acuerd celebración , pérez fernández , mixto campuzano , campuzano canadé , mixto martínez
# Topic 3:
# vasco pnv , diputada doña , desean fijar , posicion vasco , interpelacion urgent , convalidación derogación , pnv olabarría , vasco azpiazu , pnv azpiazu , vasco esteban
# Topic 4:
# sánchez llibr , fernández davila , número formula , lópez garrido , dirigida ministra , pasamo fijación , canaria mardon , legarda uriart , lópez chamosa , mixto fernández
# Topic 5:
# aprobada artículo , aprobada resto , aprobada número , aprobada disposición , dictamen sección , aprobada sección , defensa mixto , aprobada transaccion , sección relativo , aprobado artículo
# Topic 6:
# cha izquierda , icveuia cha , iu icveuia , gil lázaro , aprobado dictamen , sánchez robl , defensa formulada , plural coscubiela , vicepresidenta adelant , ocupen escaño
# Topic 7:
# convergència unió , popular congreso , catalán convergència , coalición canaria , congreso formula , poder judici , tribun constitucion , violencia género , guardia civil , proposición socialista
# Topic 8:
# unión progreso , progreso democracia , diputada ministra , medio ambient , servicio social , ir terminando , ir acabando , cultura deport , social igualdad , servicio público
# Topic 9:
# aceptación rechazo , ruego guarden , tiempo concluido , vasco olabarría , catalán sánchez , mañana hora , nombr catalán , gonzález txabarri , acepta alguna , catalán jané
# Topic 10:
# ruego concluya , vaya concluyendo , ruego vaya , rechazado número , álvarez sostr , vaya terminando , suspend mañana , democracia anchuelo , democracia martínez , diputada vicepresidenta

# %%
# Topic que presenta mayor FREX para cada bigrama
d = []
for n in enumerate(feature_names):
    d.append(
        {
            'N': n[0],
            'Bigrama': n[1],
            'Topic':  frex_df[n[0]].argsort()[9]
        }
    )

bi_topic_frex=pd.DataFrame(d)
bi_topic_frex.head(20)
# Out:
#      N                Bigrama  Topic
# 0    0              ab initio      5
# 1    1           abajo arriba      7
# 2    2      abandon hemiciclo      5
# 3    3        abandon tribuna      0
# 4    4       abandonado suert      7
# 5    5    abandonan hemiciclo      5
# 6    6    abandonar hemiciclo      2
# 7    7      abandonar tribuna      6
# 8    8    abandonen hemiciclo      5
# 9    9     abandono educativo      7
# 10  10       abandono escolar      7
# 11  11      abandono política      7
# 12  12      abandono temprano      7
# 13  13         abanico medida      7
# 14  14    abanico posibilidad      7
# 15  15         abanico salari      2
# 16  16        abarata despido      7
# 17  17     abaratamiento cost      2
# 18  18  abaratamiento despido      7
# 19  19          abaratar cost      7

# %%
# Topic que presenta mayor Weight para cada bigrama
d = []
nombres=cv.get_feature_names_out()
componentes=lda.components_.transpose()
for n in enumerate(lda.components_.transpose()):
    d.append(
        {
            'N': n[0],
            'Bigrama': nombres[n[0]],
            'Topic':  componentes[n[0]].argsort()[9]
        }
    )

pd.DataFrame(d).head(20)
# Out:
#      N                Bigrama  Topic
# 0    0              ab initio      6
# 1    1           abajo arriba      7
# 2    2      abandon hemiciclo      5
# 3    3        abandon tribuna      0
# 4    4       abandonado suert      7
# 5    5    abandonan hemiciclo      5
# 6    6    abandonar hemiciclo      2
# 7    7      abandonar tribuna      6
# 8    8    abandonen hemiciclo      5
# 9    9     abandono educativo      7
# 10  10       abandono escolar      7
# 11  11      abandono política      7
# 12  12      abandono temprano      7
# 13  13         abanico medida      7
# 14  14    abanico posibilidad      7
# 15  15         abanico salari      7
# 16  16        abarata despido      7
# 17  17     abaratamiento cost      7
# 18  18  abaratamiento despido      7
# 19  19          abaratar cost      7

# %% [markdown]
# # Base con Topics

# %%
# Ejemplo de Topic por FREX de acuerdo al bigrama más presente en ese discurso
discurso=2
print(f"Bigrama más usado: {matrix[discurso].argmax()}")
print(f"Topic: {frex_df[matrix[discurso].argmax()].argsort()[9]}")
# Out:
# Bigrama más usado: 124686
# Topic: 3

# %%
base['id']=range(0,334421)

# %%
def t_FREX(row):
  return frex_df[matrix[row['id']].argmax()].argsort()[9]

# %%
base['Topic_FREX']=base.apply (lambda row: t_FREX(row), axis=1)

# %%
# Ejemplo de Topic por weight de acuerdo al bigrama más presente en ese discurso
discurso=2
print(f"Bigrama más usado: {matrix[discurso].argmax()}")
print(f"Topic: {lda.components_.transpose()[matrix[discurso].argmax()].argsort()[9]}")
# Out:
# Bigrama más usado: 124686
# Topic: 3

# %%
def t_weight(row):
  return lda.components_.transpose()[matrix[row['id']].argmax()].argsort()[9]

# %%
base['Topic_weight']=base.apply (lambda row: t_weight(row), axis=1)

# %%
base.head(5)
# Out:
#    Unnamed: 0                                              orden  \
# 0           0  LECTURA DEL REAL DECRETO. DE CONVOCATORIA, DE ...
# 1           1                     DESIGNACION DE LA MESA DE EDAD
# 2           2                     DESIGNACION DE LA MESA DE EDAD
# 3           3  CONSTITUCION INTERINA DE LA CAMA. RA Y ELECCIO...
# 4           5  CONSTITUCION INTERINA DE LA CAMA. RA Y ELECCIO...
#
#                                           namex  \
# 0       PRESIDENTE PROVISIONAL (Fraile Poujade)
# 1                        PRESIDENTE PROVISIONAL
# 2   PRESIDENTE PROVISIONAL (Rodríguez Valverde)
# 3  PRESIDENTE PROVISIONAL (Ro.dríguez Valverde)
# 4   PRESIDENTE PROVISIONAL (Rodríguez Valverde)
#
#                                         intervention       fecha legislatura  \
# 0   Señoras y señores Diputados, se abre la sesió...  23/03/1979           I
# 1   (Fraile Poujade): Según la relación que cons....  23/03/1979           I
# 2   Siguiendo el orden del día, ruego al señor Es...  23/03/1979           I
# 3   Al reanudarse la sesión, procedería dar lectu...  23/03/1979           I
# 4   Una vez leído el informe de la Junta Electora...  23/03/1979           I
#
#    pleno                    role              oradorx  \
# 0    1.0  PRESIDENTE PROVISIONAL       FRAILE POUJADE
# 1    1.0  PRESIDENTE PROVISIONAL       FRAILE POUJADE
# 2    1.0  PRESIDENTE PROVISIONAL   RODRIGUEZ VALVERDE
# 3    1.0  PRESIDENTE PROVISIONAL  RO.DRIGUEZ VALVERDE
# 4    1.0  PRESIDENTE PROVISIONAL   RODRIGUEZ VALVERDE
#
#                                namey  ... total             oradory cataluna  \
# 0          Fraile Poujade, Modesto †  ...   4.0      FRAILE POUJADE      0.0
# 1          Fraile Poujade, Modesto †  ...   4.0      FRAILE POUJADE      0.0
# 2  Rodríguez Valverde, León Máximo †  ...   6.0  RODRIGUEZ VALVERDE      0.0
# 3  Rodríguez Valverde, León Máximo †  ...   6.0  RODRIGUEZ VALVERDE      0.0
# 4  Rodríguez Valverde, León Máximo †  ...   6.0  RODRIGUEZ VALVERDE      0.0
#
#   estatut  inter_raw          partido  \
# 0     0.0        NaN  UCD, AP-PDP, CP
# 1     0.0        NaN  UCD, AP-PDP, CP
# 2     0.0        NaN             PSOE
# 3     0.0        NaN             PSOE
# 4     0.0        NaN             PSOE
#
#                                               tokens  id Topic_FREX  \
# 0  ['señora', 'señor', 'diputado', 'abr', 'junta'...   0          5
# 1  ['frail', 'poujad', 'según', 'relación', 'con'...   1          5
# 2  ['siguiendo', 'ruego', 'esperabé', 'arteaga', ...   2          3
# 3  ['reanudars', 'procedería', 'dar', 'lectura', ...   3          6
# 4  ['leído', 'inform', 'junta', 'elector', 'centr...   4          5
#
#   Topic_weight
# 0            6
# 1            5
# 2            3
# 3            6
# 4            7
#
# [5 rows x 24 columns]

# %%
# Promedio general de bigramas únicos por discurso
(matrix != 0).sum(1).mean()
# Out:
# 24.149455327267127

# %%
# Matriz de probabilidad de topic por discurso
disc_frex=matrix*frex_df.transpose()

# %%
pd.DataFrame(disc_frex)
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.000902  0.000850  0.996083  0.000867  0.000894  0.996897  0.776830
# 1       1.311432  1.247203  1.126417  1.424518  0.842034  1.998308  0.959308
# 2       1.532685  1.421008  1.530099  2.217678  1.313264  2.369619  1.805603
# 3       0.521412  0.543214  0.871986  0.535310  0.469273  0.819066  1.002931
# 4       1.016500  1.213299  1.003653  1.379574  0.896700  1.919454  0.770886
# ...          ...       ...       ...       ...       ...       ...       ...
# 334416  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 334417  0.324500  0.316727  0.568359  0.299146  0.320558  0.321503  0.795257
# 334418  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 334419  0.418815  0.626280  1.181976  1.483105  0.592045  0.420764  1.070379
# 334420  0.990437  0.934798  1.623807  1.431209  1.112610  1.019254  3.137703
#
#                7         8         9
# 0       0.000714  0.000929  0.000894
# 1       0.370123  1.303429  1.083963
# 2       2.857327  1.297691  1.378054
# 3       0.748592  0.479033  0.519237
# 4       1.173375  0.934832  0.982908
# ...          ...       ...       ...
# 334416  0.000000  0.000000  0.000000
# 334417  1.872398  0.656868  0.329157
# 334418  0.000000  0.000000  0.000000
# 334419  1.008453  0.411899  0.422753
# 334420  2.431626  0.992791  1.051796
#
# [334421 rows x 10 columns]

# %%
# Se asigna a la base el topic por probabilidad (en vez de solamente considerar el bigrama más repetido)
base['Topic_FREX']=disc_frex.argmax(axis=1)

# %%
# Ahora lo mismo pero por weights
disc_weights=matrix*lda.components_.transpose()

# %%
pd.DataFrame(disc_weights)
# Out:
#                0         1          2          3         4          5  \
# 0       0.100007  0.100002  45.504409   0.100007  0.100003  81.584917
# 1       0.259315  0.259326   0.259316   0.424371  0.259315  14.574365
# 2       0.554463  0.554536   1.216882   9.286223  0.554499  16.041641
# 3       0.215742  0.215758   3.144330   0.215838  0.215744   8.098557
# 4       0.298002  1.102012   0.298006   3.614168  0.298001  19.005439
# ...          ...       ...        ...        ...       ...        ...
# 334416  0.000000  0.000000   0.000000   0.000000  0.000000   0.000000
# 334417  0.297447  0.297447  16.434079   0.297446  0.297449   0.297449
# 334418  0.000000  0.000000   0.000000   0.000000  0.000000   0.000000
# 334419  0.400293  5.595260  20.185683  24.058262  8.791813   0.400358
# 334420  0.621833  0.621895  28.543139   9.530247  2.566220   0.621849
#
#                  6           7         8         9
# 0       173.985013    0.100010  0.100003  0.100001
# 1         4.070087    3.689100  0.259319  0.259325
# 2        20.479805   41.893518  0.554450  0.554528
# 3        20.925129    8.100356  0.215757  0.215773
# 4         0.927025   13.691019  0.298001  0.298013
# ...            ...         ...       ...       ...
# 334416    0.000000    0.000000  0.000000  0.000000
# 334417    8.543146  104.314428  9.534516  0.297451
# 334418    0.000000    0.000000  0.000000  0.000000
# 334419   23.116286   57.990098  0.400168  0.400190
# 334420   34.746842   80.289888  0.621847  0.621825
#
# [334421 rows x 10 columns]

# %%
base['Topic_weight']=disc_weights.argmax(axis=1)

# %% [markdown]
# # LASSO por legislatura

# %%
from tabulate import tabulate
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report
import numpy as np
from numpy import argsort
import statistics
from statistics import mode

# %%
# Relevancia de bigramas en la predicción por legislatura
tabla=[]
legislaturas=['I', 'II', 'III', 'IV', 'V', 'VI', 'VII','VIII', 'IX', 'X', 'XI', 'XII','XIII']

cv=CountVectorizer(ngram_range=[2,2], stop_words=stopwords, max_df=0.95, min_df=0.001)
n=5

for x in legislaturas: 
  base_year=base[base.legislatura==x]
  
  vec = cv.fit(base_year['tokens'])
  train_matrix = vec.fit_transform(base_year['tokens']) 
  lr = LogisticRegression(penalty='l1', max_iter=50, solver='liblinear')
  lr.fit(train_matrix,base_year['party'])
  
  features=[]
  s=lr.coef_[0]
  
  print(f"Legislatura: {x} - Most Frecuent Topic: {mode(bi_topic_frex['Topic'][argsort(s)])}")
  print(tabulate([cv.get_feature_names_out()[argsort(s)[:n]], sorted(s)[:n],bi_topic_frex['Topic'][argsort(s)[:n]],cv.get_feature_names_out()[argsort(s)[-n:]], sorted(s)[-n:],  bi_topic_frex['Topic'][argsort(s)[-n:]]], tablefmt='pretty'))
# Out:
# Legislatura: I - Most Frecuent Topic: 7
# +---------------------+--------------------+---------------------+--------------------+---------------------+
# |    duda ninguna     |  contestar nombr   |   senado proyecto   |  número coalición  |    lenguaj hecho    |
# | -3.8752352108766335 | -2.858277768762358 | -2.7852824719678857 | -2.744453923397834 | -2.7283781351853524 |
# |          6          |         9          |          7          |         1          |          7          |
# | respuesta recibida  |   cualquier caso   | artículo entendemo  | socialista votado  |    pasamo examen    |
# | 1.9616180115723716  | 1.9676523209145371 |  1.972206851275881  | 2.257110384441647  | 3.1092563910999638  |
# |          7          |         6          |          6          |         6          |          6          |
# +---------------------+--------------------+---------------------+--------------------+---------------------+
# Legislatura: II - Most Frecuent Topic: 7
# +----------------------+-------------------------+--------------------+---------------------+---------------------+
# |  ponent socialista   | representant socialista |   pido cuestión    |     mismo hecho     |  separada artículo  |
# | -3.6342031938539696  |   -3.172918500721359    | -2.707430363501559 | -2.4969981787663964 | -2.4406244127825567 |
# |          7           |            8            |         7          |          7          |          7          |
# | representant popular |    consiguient creo     |  vaya terminando   |     pide martín     |  nombr socialista   |
# |  3.243230902319921   |    3.263696535158356    | 3.325690864195261  |  3.462101179393146  |  5.023486741300986  |
# |          7           |            0            |         1          |          7          |          1          |
# +----------------------+-------------------------+--------------------+---------------------+---------------------+
# Legislatura: III - Most Frecuent Topic: 7
# +---------------------+---------------------+--------------------+-----------------------+---------------------+
# |   dinero español    |     toval pide      | separada artículo  | agrupación represento |    millon parado    |
# | -3.2682405996771764 | -3.0466399223170053 | -2.865259346462524 |  -2.704294125921167   | -2.4736497292011763 |
# |          5          |          2          |         7          |           1           |          7          |
# |      vasco pnv      |     pide martín     |   ruego concluya   |   comisión delegada   |  nombr socialista   |
# |  3.317987311750813  | 3.3594906977602665  | 3.7490264081204385 |  3.8011731080532076   |  3.976576367333304  |
# |          6          |          7          |         6          |           8           |          7          |
# +---------------------+---------------------+--------------------+-----------------------+---------------------+
# Legislatura: IV - Most Frecuent Topic: 7
# +--------------------+-------------------------+--------------------+---------------------+--------------------+
# |  popular entiend   |    popular solicita     | popular considera  |    da sensación     |    ello popular    |
# | -5.985126438218527 |   -5.585210377332388    | -3.284889513502501 | -2.8656094703128705 | -2.849457915540102 |
# |         7          |            3            |         2          |          6          |         8          |
# | conjunto ciudadano | conjunto administracion |  fijar socialista  |   ruego concluya    | esfuerzo important |
# | 3.1173154170327613 |   3.4546683683510597    | 3.543058018191252  | 3.8333661158557644  | 3.920616442603182  |
# |         8          |            1            |         7          |          7          |         7          |
# +--------------------+-------------------------+--------------------+---------------------+--------------------+
# Legislatura: V - Most Frecuent Topic: 7
# +---------------------+---------------------+---------------------+--------------------+---------------------+
# |  solicito separada  |    popular quier    |     aceit oliva     |  grave perjuicio   |    sido incapaz     |
# | -3.0206172173795554 | -2.6228474478459147 | -2.6027995013492067 | -2.586234026248176 | -2.5648130111782548 |
# |          2          |          7          |          2          |         5          |          2          |
# |  aprobado dictamen  |  calidad servicio   |  portavoz popular   |   ruego concluya   |       ss hace       |
# | 3.6549107714047158  |  3.854278697597381  | 4.1681362120398395  | 4.3248634269523105 |  4.660550907483414  |
# |          3          |          6          |          6          |         6          |          6          |
# +---------------------+---------------------+---------------------+--------------------+---------------------+
# Legislatura: VI - Most Frecuent Topic: 7
# +--------------------+--------------------+-------------------------+--------------------+---------------------+
# |  unió valenciana   | restant izquierda  | representant socialista | aprobado dictamen  |       ss debe       |
# | -4.037778086776424 | -3.492371279587189 |   -3.315981840914502    | -3.246832905261593 | -3.1691413019401806 |
# |         7          |         6          |            7            |         7          |          7          |
# |   canaria gómez    |  presentado part   |    pura sencillament    |  fijar socialista  |     fijar debat     |
# | 2.296551450594773  | 2.768775394276847  |   2.8355489580595825    | 3.754997448685244  |  5.550459706026181  |
# |         7          |         0          |            7            |         6          |          6          |
# +--------------------+--------------------+-------------------------+--------------------+---------------------+
# Legislatura: VII - Most Frecuent Topic: 7
# +----------------------+---------------------+--------------------+---------------------+---------------------+
# |    número formula    |    nombr popular    | socialista formula | portavoz socialista |    popular fijar    |
# |  -5.057488668682129  | -4.5612397134137845 | -4.101262213936903 | -3.7413663778634465 | -3.461696376568619  |
# |          9           |          0          |         7          |          3          |          7          |
# | representant popular |    ciudadano paí    |    guerra ileg     | ciudadano ciudadana | socialista presentó |
# |  2.8800269918159107  |  3.135148212649789  | 3.5697326269946905 | 3.7302729456587973  |  4.599502140802794  |
# |          1           |          7          |         4          |          3          |          6          |
# +----------------------+---------------------+--------------------+---------------------+---------------------+
# Legislatura: VIII - Most Frecuent Topic: 7
# +----------------------+---------------------+--------------------+---------------------+---------------------+
# |   doy reproducida    |  intervengo nombr   |  nación española   | portavoz socialista | dirigent socialista |
# |  -4.860905983104488  | -3.6185309274735467 | -2.81165903450658  | -2.694493412014762  | -2.5893209968595468 |
# |          0           |          8          |         7          |          9          |          7          |
# | interpelacion urgent |  portavoz popular   |  turismo comercio  |    diputada doña    |  nombr socialista   |
# |  3.230111478207093   |  3.31875962973864   | 3.3937220609911822 | 3.5279637482621293  |  4.209257596175776  |
# |          6           |          8          |         3          |          9          |          8          |
# +----------------------+---------------------+--------------------+---------------------+---------------------+
# Legislatura: IX - Most Frecuent Topic: 7
# +---------------------+---------------------+--------------------+-------------------+---------------------+
# |    recort social    |    millon parado    | rodríguez zapatero |   popular quier   |  industria turismo  |
# |  -4.12340306795647  | -3.8063869654912876 | -3.216212936039293 | -3.06083741929135 | -2.7375434236562124 |
# |          6          |          6          |         9          |         7         |          6          |
# | ciudadano ciudadana |  portavoz popular   |  turismo comercio  | nombr socialista  |   popular medida    |
# | 3.7552939964081284  |  3.81250343459423   | 3.8825111944888935 | 4.097295435316389 |  4.43137945055413   |
# |          9          |          7          |         0          |         7         |          7          |
# +---------------------+---------------------+--------------------+-------------------+---------------------+
# Legislatura: X - Most Frecuent Topic: 7
# +--------------------+---------------------+--------------------+---------------------+---------------------+
# |   nombr popular    |   cultura deport    |   mismo periodo    |   toda sinceridad   |   mejor servicio    |
# | -4.476452069157782 | -3.6798947540696676 | -3.657826115379667 | -3.5923839919632203 | -3.4586092671621884 |
# |         2          |          6          |         1          |          7          |          3          |
# |  recort política   |   crisi política    | educación cultura  |      paso atrá      |    debe concluir    |
# | 3.4294413283350127 |  3.497594108010601  | 3.621102700981628  |  4.129472584000988  | 5.3833998058684625  |
# |         7          |          6          |         7          |          5          |          6          |
# +--------------------+---------------------+--------------------+---------------------+---------------------+
# Legislatura: XI - Most Frecuent Topic: 7
# +---------------------+---------------------+--------------------+--------------------+--------------------+
# |    mixto quevedo    |      mesa edad      |     vasco pnv      |   puesto trabajo   |    alguna sido     |
# | -2.4323829726099255 | -2.0790913071749935 | -1.962225759281479 | -1.955080665157697 | -1.869857043444897 |
# |          7          |          7          |         6          |         6          |         6          |
# |    papel panamá     |    vota término     |  español española  |    miguel ángel    |   podemosen comú   |
# | 0.6210581961891273  | 0.6272601339793412  | 0.8545061937992657 | 0.8666914785225569 | 0.9283196142829793 |
# |          6          |          7          |         7          |         6          |         7          |
# +---------------------+---------------------+--------------------+--------------------+--------------------+
# Legislatura: XII - Most Frecuent Topic: 7
# +--------------------+--------------------+--------------------+---------------------+--------------------------+
# |     ana maría      |   quieren romper   |    miembro mesa    |      vasco pnv      | industria competitividad |
# | -5.507132175835339 | -5.269866066879036 | -5.086694736582315 | -4.3625175410034105 |    -3.858288162342144    |
# |         6          |         7          |         8          |          1          |            3             |
# |   ciudadano paí    |  nombr socialista  |  comercio turismo  | socialista queremo  |       nombr mixto        |
# | 3.286100734366013  | 3.2967391104539505 | 3.8859223637681914 | 3.9713701184882333  |    4.930507407931981     |
# |         7          |         7          |         6          |          5          |            8             |
# +--------------------+--------------------+--------------------+---------------------+--------------------------+
# Legislatura: XIII - Most Frecuent Topic: 7
# +----------------------+---------------------+----------------------+--------------------+--------------------+
# |    dinero español    |      si hacemo      | president socialista |     hace mese      |   mejor sistema    |
# | -2.9341093942721197  | -2.7362141716314405 | -2.5293698520477017  | -2.329937739436301 | -2.274075635292419 |
# |          4           |          6          |          6           |         4          |         7          |
# | administración gener |    medida urgent    |  pesca alimentación  |   toda cuestion    |    duda alguna     |
# |  0.7293734989563163  | 0.8194346615406323  |  0.9662105702763626  | 1.007508164662237  | 1.1133561358329265 |
# |          6           |          7          |          3           |         7          |         3          |
# +----------------------+---------------------+----------------------+--------------------+--------------------+

# %% [markdown]
# # LASSO por año

# %%
# Relevancia de bigramas en la predicción por año
tabla=[]

nombres=cv.get_feature_names_out()
componentes=lda.components_.transpose()
n = 5

for x in range (1979, 2010): 
  base_year=base[pd.DatetimeIndex(base.fecha).year==x]
  train_matrix = vec.fit_transform(base_year['tokens'])
  y_train= base_year['party']
  lr = LogisticRegression(penalty='l1', max_iter=1000, solver='liblinear')
  lr.fit(train_matrix,y_train)

  s = lr.coef_[0]
    
  print(f"Año: {x}")
  print(tabulate([cv.get_feature_names_out()[argsort(s)[:n]], sorted(s)[:n],bi_topic_frex['Topic'][argsort(s)[:n]],cv.get_feature_names_out()[argsort(s)[-n:]], sorted(s)[-n:],  bi_topic_frex['Topic'][argsort(s)[-n:]]], tablefmt='pretty'))
# Out:
# Año: 1979
# +---------------------+--------------------+---------------------+---------------------+--------------------+
# |  correspond ahora   |   foral navarra    |   nombr centrista   |      quier uso      |  cuestión previa   |
# | -3.2193442231019627 | -2.567572448927969 | -1.9372835735574527 | -1.8362037346044535 | -1.811162857078032 |
# |          9          |         7          |          6          |          7          |         1          |
# |  socialista votado  |   cualquier caso   | ningún inconvenient |  nombr socialista   | formacion política |
# | 1.4360795433298517  | 1.470023792237444  |  1.541011394531198  | 1.5442987698558934  | 1.963851738858638  |
# |          6          |         7          |          6          |          7          |         3          |
# +---------------------+--------------------+---------------------+---------------------+--------------------+
# Año: 1980
# +---------------------+--------------------+---------------------+----------------------+---------------------+
# |  aprobado artículo  |    duda ninguna    |   senado proyecto   |      pérez ruiz      |   aprobado número   |
# | -2.5123829444387296 | -2.509762726180747 | -2.1387483450965186 |  -2.050059388925129  | -2.0462212267409945 |
# |          1          |         9          |          7          |          7           |          7          |
# |   cualquier caso    |   respond nombr    |    cuanto número    | efecto desarrollarla |    pasamo examen    |
# |  1.799981900009017  | 1.8782570884051912 | 2.0898792609856534  |  2.2316912310256622  | 2.6210041459979436  |
# |          6          |         3          |          9          |          7           |          1          |
# +---------------------+--------------------+---------------------+----------------------+---------------------+
# Año: 1981
# +-------------------------+---------------------+-----------------------+---------------------+-------------------------+
# | contestar interpelación |   contestar nombr   | órgano administración |      si desea       | interpelación formulada |
# |   -2.483139205501725    | -2.1716883447412187 |  -1.7252294088152125  | -1.7190179196760034 |   -1.6925526518412763   |
# |            1            |          7          |           2           |          9          |            7            |
# |      unión centro       |   senado artículo   |  presupuesto general  |      si permit      |     pedimo separada     |
# |   1.3577712682302028    | 1.3797212809708017  |  1.4763360827121024   | 1.4782366571759136  |   1.7848137517886797    |
# |            7            |          7          |           7           |          0          |            2            |
# +-------------------------+---------------------+-----------------------+---------------------+-------------------------+
# Año: 1982
# +---------------------+-----------------------+-------------------------+--------------------+----------------------+
# |    duda ninguna     | función fiscalizadora | interpelación formulada |    debat pausa     |    fuerza cámara     |
# | -2.7714930257956363 |  -2.5694170634253433  |   -1.7865246906197023   | -1.71846426128433  | -1.6698970149018728  |
# |          1          |           7           |            7            |         4          |          7           |
# |  popular congreso   |    cualquier caso     |    separada artículo    |  resolv problema   | jurisdicción contabl |
# | 1.2170351129548433  |   1.285234515221038   |   1.2914552591477764    | 1.3318227138025127 |  1.415559913684678   |
# |          4          |           6           |            7            |         5          |          3           |
# +---------------------+-----------------------+-------------------------+--------------------+----------------------+
# Año: 1983
# +--------------------+--------------------+---------------------+---------------------+----------------------+
# | ponent socialista  |   banca privada    |      cuál sido      |    pido cuestión    |   quiero insistir    |
# | -3.586874667580726 | -2.443199765566201 | -2.4330684175563855 | -2.2766905939210744 |  -2.149631638074015  |
# |         8          |         7          |          7          |          0          |          8           |
# | crecimiento ciento |    lópez lerma     |  aténgas cuestión   |   vaya terminando   | representant popular |
# | 2.462625847968207  | 2.465564394703041  |  2.620547845680313  | 2.6243273126144233  |  3.9673573440229823  |
# |         9          |         6          |          7          |          7          |          6           |
# +--------------------+--------------------+---------------------+---------------------+----------------------+
# Año: 1984
# +--------------------+--------------------------+--------------------+---------------------+---------------------+
# | ponent socialista  | representant socialista  | separada artículo  |   protesta banco    |    banco derecha    |
# | -2.919232133754051 |    -2.890576252413535    | -2.830187383041178 | -2.7051183453484313 | -2.5841550486666836 |
# |         6          |            6             |         8          |          0          |          6          |
# |  terminado tiempo  | radiotelevisión española |     vasco pnv      |  herrero rodríguez  |  nombr socialista   |
# | 2.5448565980881215 |    2.557717618423688     | 2.562378791112034  |  2.570896424143774  | 2.9291325472841865  |
# |         7          |            6             |         7          |          7          |          7          |
# +--------------------+--------------------------+--------------------+---------------------+---------------------+
# Año: 1985
# +--------------------+-------------------------+---------------------+---------------------+--------------------+
# |  máxima brevedad   | representant socialista |    pido cuestión    |    jefe servicio    | mayoritario cámara |
# | -3.664061133154419 |   -3.018903765144279    | -2.8697441507033843 | -2.7322628520371444 | -2.726112871651785 |
# |         6          |            6            |          7          |          5          |         6          |
# |   mixto suscrita   |      bravo laguna       |    peseta millon    |  nombr socialista   |  portavoz popular  |
# | 2.4061374888353995 |    2.665530522409731    | 2.8623246963518856  | 3.1315557437850154  | 4.402306533284802  |
# |         8          |            7            |          1          |          8          |         5          |
# +--------------------+-------------------------+---------------------+---------------------+--------------------+
# Año: 1986
# +------------------------+---------------------+--------------------+---------------------+---------------------+
# |    sociedad moderna    |  portavoz minoría   |   pide separada    | democracia española |  separada artículo  |
# |  -3.5912875457301365   | -3.2919034070253095 | -3.241869099441042 | -3.107609340109888  | -3.0399136558391646 |
# |           6            |          9          |         9          |          2          |          6          |
# | unidaesquerra catalana |   junta portavoc    | política monetaria |   ruego concluya    | organismo autónomo  |
# |   1.5247556128127455   |  1.592300028757503  | 1.6337743835687846 | 1.9639437140146576  |  2.080420324030058  |
# |           8            |          6          |         6          |          8          |          7          |
# +------------------------+---------------------+--------------------+---------------------+---------------------+
# Año: 1987
# +---------------------+--------------------+---------------------+---------------------+---------------------+
# | representant pueblo |     pre sident     |     sino falta      |  separada artículo  |   pedimo separada   |
# | -3.6136674417437007 | -3.528514885179673 | -3.3326228342433972 | -3.1772311984572847 | -2.6144090552163086 |
# |          6          |         7          |          9          |          6          |          6          |
# |    bravo laguna     |   toda comunidad   |    puesto marcha    |  nombr socialista   |   banco izquierda   |
# | 2.9410263880598837  | 3.0474695413167425 |  3.095911244866412  |  3.139009090108168  | 3.4048027938481824  |
# |          1          |         8          |          7          |          6          |          7          |
# +---------------------+--------------------+---------------------+---------------------+---------------------+
# Año: 1988
# +---------------------+-----------------------+---------------------+--------------------------+---------------------+
# |    si ministerio    | constitución artículo |  artículo tercero   | interpelación presentada |    da casualidad    |
# | -2.7044809844149773 |  -2.6811199208875327  | -2.4546469785206626 |   -2.4529240757568713    | -2.3905646606513775 |
# |          7          |           4           |          3          |            7             |          9          |
# |     pérez dobón     |      algún modo       | propia constitución |      ruego concluya      |    puedo decirl     |
# | 2.4606554739269964  |  2.4911306657997114   | 2.7296018273555887  |    3.112932239702918     |  3.198921299351271  |
# |          3          |           6           |          7          |            6             |          3          |
# +---------------------+-----------------------+---------------------+--------------------------+---------------------+
# Año: 1989
# +---------------------+---------------------+---------------------+-----------------------+---------------------+
# |    medida piensa    |  dejar constancia   |      da cuenta      |     rumor aplauso     |   contrato siglo    |
# | -3.6355952112708874 | -3.5385847812640776 | -3.1336286061643723 |   -3.10107206216299   | -2.8096370604202514 |
# |          1          |          6          |          4          |           7           |          6          |
# |     creo bueno      |    bravo laguna     |  haciendo esfuerzo  | reforma universitaria |   ruego concluya    |
# | 1.5427701066268869  | 1.7015157766748787  | 1.7290007692879632  |  1.7317617550157198   |  2.311887804773699  |
# |          6          |          6          |          3          |           6           |          7          |
# +---------------------+---------------------+---------------------+-----------------------+---------------------+
# Año: 1990
# +--------------------+---------------------+---------------------+--------------------+--------------------+
# |  popular solicita  |  separada artículo  |     parec grave     |    ello popular    |   felip gonzález   |
# | -4.098789275377804 | -3.1634575510028555 | -2.9973676911071974 | -2.947459853196234 | -2.645636775090744 |
# |         7          |          7          |          6          |         8          |         4          |
# |     otero nova     |     parec razon     |  banco socialista   |  ningún problema   |   ruego concluya   |
# | 2.0475852243475794 | 2.2139585073107573  |  2.454153960772121  | 2.900020117227764  | 2.955777616873494  |
# |         8          |          6          |          7          |         7          |         8          |
# +--------------------+---------------------+---------------------+--------------------+--------------------+
# Año: 1991
# +--------------------+-----------------------+-------------------------+--------------------+---------------------+
# |  popular solicita  | particular presentado | representant socialista |      mismo si      | falta sensibilidad  |
# | -5.680542643037359 |  -3.7448649364521223  |   -3.613164898797426    | -3.228023832169658 | -2.7433537542734205 |
# |         6          |           7           |            6            |         6          |          0          |
# |  línea actuación   |    ruego concluya     |      nuevo código       |  pública empresa   |     debo decirl     |
# | 2.365531945174126  |  2.5099026880824935   |   2.5206857313615494    | 2.638299528291861  |  2.841138564388301  |
# |         7          |           8           |            7            |         8          |          9          |
# +--------------------+-----------------------+-------------------------+--------------------+---------------------+
# Año: 1992
# +---------------------+---------------------+--------------------+--------------------+--------------------+
# |  popular solicita   |    fijar popular    |  autovía leizarán  |   medida piensa    | popular considera  |
# | -5.034224488914539  | -3.6074128998263864 | -3.457393771601404 | -3.287713612007578 | -3.266890280816818 |
# |          2          |          0          |         7          |         7          |         1          |
# | situación económica | momento determinado |   ninguna manera   |   garcía fonseca   |   ruego concluya   |
# | 2.1651746806162833  |  2.459783862908847  | 2.558286972075587  | 2.5925146891088366 | 3.4999650252474925 |
# |          1          |          7          |         7          |         7          |         9          |
# +---------------------+---------------------+--------------------+--------------------+--------------------+
# Año: 1993
# +-------------------+---------------------+--------------------+----------------------+----------------------+
# | popular solicita  |     resto bloqu     |   present cámara   |  solicito separada   | consideración cámara |
# | -4.20099201246402 | -3.4362894360796874 | -3.299521504783213 | -3.1945128334856654  |  -3.127663155345445  |
# |         1         |          9          |         4          |          6           |          6           |
# | aprobado dictamen |   momento actual    |  gonzález lizondo  | representant popular |    ruego concluya    |
# | 2.410094508806195 |  2.479550752153408  | 2.5812416257619826 |  2.6370375822061254  |   3.26653072724495   |
# |         6         |          3          |         4          |          7           |          7           |
# +-------------------+---------------------+--------------------+----------------------+----------------------+
# Año: 1994
# +--------------------+---------------------+---------------------+---------------------+---------------------+
# |  postura popular   |   grave perjuicio   |    da sensación     |     mundo labor     |       van dar       |
# | -4.170759516795895 | -3.9169034150056157 | -3.3454241851558564 | -3.2775413875330415 | -3.0467819574348454 |
# |         7          |          1          |          7          |          7          |          6          |
# |  fijar socialista  |  aprobado dictamen  |  portavoz popular   |  congreso formula   |   ruego concluya    |
# | 2.8287805344915675 | 2.8707310488075364  | 3.2035386732514914  |  3.475758024729518  |  3.522819787025986  |
# |         7          |          9          |          6          |          6          |          6          |
# +--------------------+---------------------+---------------------+---------------------+---------------------+
# Año: 1995
# +--------------------+--------------------+---------------------------+---------------------+-------------------+
# |   ejerc derecho    |  unión valenciana  | departamento ministerial  |   público privado   |   sido incapaz    |
# | -3.692830342675129 | -3.653629135437451 |    -3.143089874678689     | -2.7003746263341606 | -2.66294231458797 |
# |         7          |         9          |             6             |          2          |         3         |
# |  régimen jurídico  |   ruego concluya   | ministerio administracion |  congreso formula   | portavoz popular  |
# | 2.854059772087399  | 2.9874278769441647 |    3.1005572907348036     | 3.1322745871551927  | 4.167220498376411 |
# |         7          |         2          |             6             |          7          |         8         |
# +--------------------+--------------------+---------------------------+---------------------+-------------------+
# Año: 1996
# +-------------------+--------------------+---------------------+---------------------+----------------------+
# |  número formula   |     ruego vaya     |  congreso formula   |   vuelvo repetir    |   unión valenciana   |
# | -3.7764032142111  | -3.736234618731331 | -3.2225267362462273 | -2.5237230229112555 | -2.2180500317662117  |
# |         8         |         6          |          7          |          6          |          7           |
# |  amparo artículo  |   vi legislatura   |   presentado part   |   guarden quiera    | convalidación desean |
# | 2.576852768942583 |  2.67933613387631  |  2.69276284949312   | 2.7402714311683876  |  3.610549133679333   |
# |         7         |         4          |          9          |          7          |          7           |
# +-------------------+--------------------+---------------------+---------------------+----------------------+
# Año: 1997
# +--------------------+--------------------+----------------------+----------------------+---------------------+
# |   número formula   |      ademá si      | presentación defensa | modernización sector |   grado consenso    |
# | -4.664434062867428 | -3.150711963300423 | -2.9684879791972625  |  -2.841115526289424  | -2.5406551371907526 |
# |         7          |         6          |          7           |          6           |          6          |
# |     si acepta      |  seguir diciendo   |   presentado part    |  elemento important  |     fijar debat     |
# | 2.497866010171237  | 2.6669722498548154 |  2.852480236340927   |  2.8547357049827746  |  4.441445527239752  |
# |         7          |         6          |          6           |          7           |          1          |
# +--------------------+--------------------+----------------------+----------------------+---------------------+
# Año: 1998
# +---------------------+---------------------+---------------------+---------------------+--------------------+
# |     maría aznar     |   popular entiend   |     ruego vaya      | portavoz socialista | aprobado artículo  |
# | -2.7678732101205736 | -2.6114715247171563 | -2.4731703221832606 | -2.399142862293835  | -2.388117736125174 |
# |          8          |          5          |          6          |          6          |         6          |
# |    ciudadano paí    | ciudadano ciudadana |     catalán gil     |  fijar socialista   |    fijar debat     |
# |  2.416819932478029  | 2.4612409635931227  | 2.4967107253147045  |  4.041154668935624  | 5.067719479194852  |
# |          6          |          6          |          9          |          6          |         1          |
# +---------------------+---------------------+---------------------+---------------------+--------------------+
# Año: 1999
# +---------------------+--------------------+--------------------+---------------------+---------------------+
# | texto interpelación |    nombr feder     |  congreso formula  |     ruego vaya      |    nombr popular    |
# | -3.7727160245745943 | -3.328253633630018 | -3.28430003002651  | -3.1920777340717947 | -3.0343527745558556 |
# |          6          |         6          |         7          |          7          |          7          |
# | compañía telefónica | finalment popular  |     si acepta      |   vaya terminando   |     fijar debat     |
# | 2.3029769384458905  | 2.3039244481119296 | 2.3095124995972682 | 2.9360407958368118  |  4.849500736175174  |
# |          7          |         7          |         8          |          6          |          6          |
# +---------------------+--------------------+--------------------+---------------------+---------------------+
# Año: 2000
# +---------------------+--------------------+---------------------+--------------------+--------------------+
# | portavoz socialista | socialista formula |   número formula    |  congreso formula  |   diálogo social   |
# | -3.354209217816765  | -3.086829115786972 | -2.9523334247509037 | -2.624929506962108 | -2.38977856931564  |
# |          3          |         6          |          6          |         5          |         6          |
# |   medida concreta   |    país europa     |  nombr socialista   |   ciudadano paí    |  socialista cree   |
# |  2.301474528359089  | 2.5712174229763325 |  2.584172987123266  | 2.6452555225985357 | 2.7044162479336853 |
# |          7          |         7          |          6          |         1          |         7          |
# +---------------------+--------------------+---------------------+--------------------+--------------------+
# Año: 2001
# +--------------------+--------------------+----------------------+--------------------+--------------------+
# |   número formula   | socialista formula |    ruego concluya    |  congreso formula  | artículo estatuto  |
# | -3.825370636140024 | -3.380092758222251 | -3.0507577500094576  | -3.030147575659989 | -2.935628783668526 |
# |         6          |         7          |          7           |         6          |         9          |
# |  concluido tiempo  |  portavoz popular  | representant popular |   mile ciudadano   |    pasamo debat    |
# | 2.944419076487969  | 3.207848425091513  |  3.3632800713857307  | 3.4574146901834006 | 3.6641292757394215 |
# |         7          |         6          |          7           |         1          |         4          |
# +--------------------+--------------------+----------------------+--------------------+--------------------+
# Año: 2002
# +--------------------+---------------------+--------------------+---------------------+--------------------+
# |   número formula   | portavoz socialista |  programa elector  |        si ss        |   cultura deport   |
# | -3.815780614023846 | -3.8147910856882326 | -2.587162031592034 | -2.5834812679148573 | -2.434479953850919 |
# |         3          |          7          |         3          |          6          |         9          |
# |    marea negra     |   leo textualment   |  quiero preguntar  |   cuenta secreta    |   recort derecho   |
# |  2.95997548727328  | 3.0865123304907827  | 3.125511880604716  |  3.175929230018274  | 3.2791143559732694 |
# |         5          |          6          |         6          |          7          |         6          |
# +--------------------+---------------------+--------------------+---------------------+--------------------+
# Año: 2003
# +--------------------+--------------------------+--------------------+---------------------+---------------------+
# |   nombr popular    |      número formula      | alianza atlántica  |    españa hecho     | portavoz socialista |
# | -3.999776095025862 |   -3.9356155121090333    | -3.809374961504782 | -3.7816527748207203 | -3.6196109139729753 |
# |         6          |            6             |         6          |          4          |          7          |
# |   romero tejada    | aniversario constitución |   ataqu militar    |    alguna medida    |     guerra ileg     |
# | 2.6677479423293615 |    2.7431288131505682    | 2.9615980907853143 | 3.0513842200449206  | 3.2620222824023366  |
# |         8          |            1             |         6          |          7          |          7          |
# +--------------------+--------------------------+--------------------+---------------------+---------------------+
# Año: 2004
# +---------------------+---------------------+---------------------+---------------------+--------------------+
# |   doy reproducida   |    nuevo talant     |   talant diálogo    | portavoz socialista | decisión política  |
# | -3.4353944343727285 | -2.8143417862414357 |  -2.8036725362523   | -2.755247704340404  | -2.723670041618228 |
# |          0          |          7          |          6          |          7          |         8          |
# |    torno ciento     |  disposición final  | popular presupuesto |    ninguna duda     | pesca alimentación |
# | 1.8743694993950868  | 2.0660137274104033  | 2.0976141099449817  | 2.1980569754325243  | 2.3759788675462246 |
# |          0          |          7          |          7          |          9          |         7          |
# +---------------------+---------------------+---------------------+---------------------+--------------------+
# Año: 2005
# +-----------------------+--------------------+---------------------+---------------------+--------------------+
# | respond interpelación |  doy reproducida   | tripartito catalán  | portavoz socialista |   millon español   |
# |   -5.13895650705606   | -4.720189360184756 | -3.6855018994851623 | -3.306904668090889  | -2.779517251378651 |
# |           6           |         7          |          9          |          7          |         7          |
# |       así hecho       |  integr violencia  |    diputada doña    |  turismo comercio   |  portavoz popular  |
# |  1.8818604568679516   | 1.975009424109929  |  1.999532855947423  | 2.7461996353268456  | 2.8830915751987956 |
# |           7           |         7          |          9          |          6          |         7          |
# +-----------------------+--------------------+---------------------+---------------------+--------------------+
# Año: 2006
# +---------------------+---------------------+--------------------+---------------------+---------------------+
# |   doy reproducida   |    lópez aguilar    |  detencion ilegal  | dirigent socialista | portavoz socialista |
# | -4.2824795238652476 | -3.3137128825376823 | -3.205285741618431 |  -2.95092287087529  | -2.5984847775358006 |
# |          3          |          0          |         7          |          4          |          6          |
# | presupuesto ciento  |      si leído       |   españa plural    |  portavoz popular   |  turismo comercio   |
# | 2.4947492105088007  | 2.5270048164745345  | 2.8534349874329603 |  3.26209710098242   | 3.3559232002844723  |
# |          6          |          4          |         6          |          6          |          7          |
# +---------------------+---------------------+--------------------+---------------------+---------------------+
# Año: 2007
# +---------------------+---------------------+--------------------+---------------------+---------------------+
# |       van dar       |     derrota eta     |  problema español  | posicion socialista |    kale borroka     |
# | -3.3431904708978735 | -3.3059663865629707 | -3.093408828455932 | -3.0380044604526586 | -2.8806046036236284 |
# |          7          |          7          |         7          |          2          |          4          |
# |      josé lui       |   conjunto medida   |  tiempo concluido  |  nombr socialista   |     partir ahí      |
# | 2.1960596580566487  |  2.402036027347241  | 2.426033508779656  |  2.517670842311387  |  2.714160170765426  |
# |          3          |          3          |         6          |          6          |          6          |
# +---------------------+---------------------+--------------------+---------------------+---------------------+
# Año: 2008
# +--------------------+---------------------+---------------------+---------------------+--------------------+
# |  sistema pension   |     ciento mile     | persona dependient  |      doce mese      |   millon español   |
# | -3.223452053654221 | -3.174573438303891  | -3.1053389780473157 | -3.0776313922419147 | -2.790354016710848 |
# |         7          |          7          |          0          |          4          |         7          |
# |    ir acabando     | actividad económica |   mercado trabajo   |   catalunya verd    |  turismo comercio  |
# | 1.8097477495243341 | 1.8857390385680346  | 1.9019210887205988  | 2.5362370659055227  | 3.466397382764486  |
# |         4          |          2          |          7          |          7          |         6          |
# +--------------------+---------------------+---------------------+---------------------+--------------------+
# Año: 2009
# +---------------------+---------------------+---------------------+----------------------+--------------------+
# |  tarifa eléctrica   |   millon empresa    |    millon parado    |    gustaría saber    |     debe haber     |
# | -3.6206821888354255 | -3.1816491310904382 | -3.0137040403006146 |  -2.948248701117129  | -2.794240908414771 |
# |          7          |          9          |          2          |          7           |         7          |
# |    puesto marcha    |  portavoz popular   |  turismo comercio   | exterior cooperación |  nombr socialista  |
# | 2.1576909715911645  |  2.238559811418891  |  2.489242032779013  |  2.905450823256589   | 3.193160345658899  |
# |          1          |          7          |          1          |          7           |         8          |
# +---------------------+---------------------+---------------------+----------------------+--------------------+
